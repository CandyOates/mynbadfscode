# %%
# %matplotlib inline
import pandas as pd
import urllib2
import bs4
import re
import datetime
import unidecode
import numpy as np
import time
import itertools
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 16)

# %% [markdown]
# ### TODO:
# - url to player's page is 'http://www.hockey-reference.com/players/%s/%s.html' % (pid[0], pid)
# - url to player's gamelogs is 'http://www.hockey-reference.com/players/%s/%s/gamelog/%d/' % (pid[0], pid, year) where year is the 2nd year of the season (2015-2016 => year=2016)

# %%
def get_player_list():
    BASEURL = 'http://www.hockey-reference.com'
    URL = '%s/players' % BASEURL
    dic = dict(LEAGUE=[], NAME=[], PID=[], START_YEAR=[], END_YEAR=[], POS=[], HEIGHT=[], WEIGHT=[], BIRTHDAY=[])
    for i in range(97, 97+26):
        letter = chr(i)
        url = '%s/%s/' % (URL, letter)
        try:
            page = urllib2.urlopen(url)
        except:
            print letter, 'page not found'
            continue
        html = page.read()
        soup = bs4.BeautifulSoup(html, "lxml")
        
        rows = soup.findAll('tr')[1:]
        for row in rows:
            lg = row['class'][0]
            items = row.findAll('td')
            a = items[0].find('a')
            name = unidecode.unidecode(a.text)
            href = a['href']
            try:
                pid = re.search('/players/%s/(.+)\.html' % letter, href).group(1)
            except:
                continue
            
            try:
                yr0 = int(items[1].text)
            except ValueError:
                yr0 = None
            
            try:
                yr1 = int(items[2].text)
            except ValueError:
                yr1 = None
            
            pos = items[3].text
            hgt = items[4].text
            
            try:
                wgt = int(items[5].text)
            except ValueError:
                wgt = None
            
            try:
                bd = datetime.datetime.strptime(items[6].text, '%B %d, %Y').date()
            except:
                bd = None
            
            dic['LEAGUE'].append(lg)
            dic['NAME'].append(name)
            dic['PID'].append(pid)
            dic['START_YEAR'].append(yr0)
            dic['END_YEAR'].append(yr1)
            dic['POS'].append(pos)
            dic['HEIGHT'].append(hgt)
            dic['WEIGHT'].append(wgt)
            dic['BIRTHDAY'].append(bd)
    return pd.DataFrame(dic)

# pl = get_player_list()

# %%
# pl.to_csv('/Users/andingo/Desktop/NHL/data/playerlist.csv')

# %%
pl = pd.read_csv('/Users/andingo/Desktop/NHL/data/playerlist.csv')

# %%
def get_gamelog_url(pid, season):
    return 'http://www.hockey-reference.com/players/%s/%s/gamelog/%d/' % (pid[0], pid, season)

def get_player_gamelogs(pid, season):
    url = get_gamelog_url(pid, season)
    page = urllib2.urlopen(url)
    html = page.read()
    soup = bs4.BeautifulSoup(html, 'lxml')
    
    cols = [x.text for x in soup.findAll('thead')[0].findAll('tr')[1].findAll('th')]
    if cols[5] == '':
        cols[5] = 'H/A'
    if cols[7] == '':
        cols[7] = 'W/L'
    FLAG = True
    FLAG2 = True
    for k, col in enumerate(cols):
        if FLAG2:
            if col == 'G':
                cols[k] = 'GM_NUM'
                FLAG2 = False
        if FLAG:
            cols[k] = 'GOAL_%s' % col if col in ('EV','PP','SH','GW') else col
        else:
            cols[k] = 'AST_%s' % col if col in ('EV','PP','SH','GW') else col
        if col == 'GW':
            FLAG = False
    
    output = []
    for row in soup.findAll('tbody')[0].findAll('tr'):
        if row['class'] != ['']:
            continue
        
        items = [x.text for x in row.findAll('td')]
        items = map(lambda x: 0 if x == '' else x, items)
        for i in range(len(items)):
            try:
                if '.' in items[i]:
                    items[i] = float(items[i])
                else:
                    items[i] = int(items[i])
            except:
                try:
                    items[i] = datetime.datetime.strptime(items[i], '%Y-%m-%d').date()
                except:
                    try:
                        m, s = items[i].split(':')
                        items[i] = int(m) + int(s)/60.
                    except:
                        pass
            
        output.append(items)
    
    output = pd.DataFrame(output, columns=cols)
    output['H/A'][output['H/A']==0] = 'v'
    output['PID'] = pid
    output['GID'] = ['%s@%s%s' % (t,o,d) if ha=='@' else '%s@%s%s' % (o,t,d) for i,d,t,ha,o in output[['Date','Tm','H/A','Opp']].itertuples()]
    output['SEASON'] = season
    return output

# gl = get_player_gamelogs(pl.PID.iloc[0], 1999)

# %%
start_time = time.time()
global_stats = pd.DataFrame()
goalie_stats = pd.DataFrame()
pids = pl[(pl.END_YEAR>=2015) & (pl.LEAGUE=='nhl')].PID
tmp = pl.set_index('PID')
for k, pid in enumerate(pids):
#     if k < 468:
#         continue
    print pid, '%d / %d' % (k, len(pids))
    if tmp.loc[pid].START_YEAR < 2016:
        try:
            gl = get_player_gamelogs(pid, 2015)
            try:
                global_stats = global_stats.append(gl, ignore_index=True)
            except:
                goalie_stats = goalie_stats.append(gl, ignore_index=True)
        except Exception, e:
            print pid, 'error in 2015', get_gamelog_url(pid, 2015), e.message
    
    if tmp.loc[pid].END_YEAR == 2016:
        try:
            gl = get_player_gamelogs(pid, 2016)
            try:
                global_stats = global_stats.append(gl, ignore_index=True)
            except:
                goalie_stats = goalie_stats.append(gl, ignore_index=True)
        except Exception, e:
            print pid, 'error in 2016', get_gamelog_url(pid, 2016), e.message
print 'Time Elapsed:', time.time() - start_time
# Out:
# abdelju01 0 / 1100
# actonwi01 1 / 1100
# adamlu01 2 / 1100
# adamscr01 3 / 1100
# agozzan01 4 / 1100
# akesoja01 5 / 1100
# allenbr01 6 / 1100
# allenco01 7 / 1100
# allenja01 8 / 1100
# altma01 9 / 1100
# alzneka01 10 / 1100
# anderfr01 11 / 1100
# andercr01 12 / 1100
# anderjo05 13 / 1100
# anderjo03 14 / 1100
# andrean01 15 / 1100
# andrisv01 16 / 1100
# angelmi01 17 / 1100
# anisiar01 18 / 1100
# arcobma01 19 / 1100
# armiajo01 20 / 1100
# arvidvi01 21 / 1100
# ashtoca01 22 / 1100
# athanan01 23 / 1100
# atkinca01 24 / 1100
# aulieke01 25 / 1100
# bachmri01 26 / 1100
# backeda01 27 / 1100
# backlmi01 28 / 1100
# backsni02 29 / 1100
# backsni01 30 / 1100
# baertsv01 31 / 1100
# baileca01 32 / 1100
# bailejo01 33 / 1100
# ballake01 34 / 1100
# barbema01 35 / 1100
# barkoal01 36 / 1100
# barrity01 37 / 1100
# bartkma01 38 / 1100
# bartlvi01 39 / 1100
# bassco01 40 / 1100
# bassco01
# /Users/andingo/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/andingo/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:18: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
#  error in 2015 http://www.hockey-reference.com/players/b/bassco01/gamelog/2015/ list index out of range
# baunky01 41 / 1100
# beaglja01 42 / 1100
# beaucfr01 43 / 1100
# beaulna01 44 / 1100
# beckta01 45 / 1100
# belesma01 46 / 1100
# bellepi01 47 / 1100
# bellebr01 48 / 1100
# bennja01 49 / 1100
# bennjo01 50 / 1100
# bennebe01 51 / 1100
# bennesa01 52 / 1100
# benoian01 53 / 1100
# bergese01 54 / 1100
# bergepa01 55 / 1100
# berglpa01 56 / 1100
# bernijo01 57 / 1100
# bernist01 58 / 1100
# berrare01 59 / 1100
# bertsch02 60 / 1100
# berubje02 61 / 1100
# bickest01 62 / 1100
# bickebr01 63 / 1100
# biegaal01 64 / 1100
# biegada01 65 / 1100
# biekske01 66 / 1100
# bigrach01 67 / 1100
# binnijo01 68 / 1100
# bishobe01 69 / 1100
# bitetan01 70 / 1100
# bjugsni01 71 / 1100
# blackje01 72 / 1100
# blandjo01 73 / 1100
# blumjo02 74 / 1100
# blundmi01 75 / 1100
# bobrose01 76 / 1100
# bodietr01 77 / 1100
# bodnaan01 78 / 1100
# bodnaan01 error in 2015 http://www.hockey-reference.com/players/b/bodnaan01/gamelog/2015/ list index out of range
# boedkmi01 79 / 1100
# bogosza01 80 / 1100
# boldual01 81 / 1100
# bollja01 82 / 1100
# bollada01 83 / 1100
# bollibr01 84 / 1100
# boninni01 85 / 1100
# boothda01 86 / 1100
# bordepa02 87 / 1100
# borowma01 88 / 1100
# borturo01 89 / 1100
# bouchre01 90 / 1100
# boulter01 91 / 1100
# boumala01 92 / 1100
# bournmi01 93 / 1100
# bourqga01 94 / 1100
# bourqre01 95 / 1100
# bourqry01 96 / 1100
# bouwmja01 97 / 1100
# bowmadr01 98 / 1100
# boychjo01 99 / 1100
# boychza01 100 / 1100
# boyesbr01 101 / 1100
# boylebr01 102 / 1100
# boyleda01 103 / 1100
# bozakty01 104 / 1100
# brassde01 105 / 1100
# braunju01 106 / 1100
# brenntj01 107 / 1100
# breweer01 108 / 1100
# brickco01 109 / 1100
# brierda01 110 / 1100
# brodema01 111 / 1100
# broditj01 112 / 1100
# brodijo01 113 / 1100
# brodzky01 114 / 1100
# brossla01 115 / 1100
# brouiju01 116 / 1100
# brouwtr01 117 / 1100
# brownch01 118 / 1100
# browndu01 119 / 1100
# brownjt01 120 / 1100
# brownmi02 121 / 1100
# brownpa02 122 / 1100
# brunnda01 123 / 1100
# bryzgil01 124 / 1100
# bulmebr01 125 / 1100
# bulmebr01 error in 2015 http://www.hockey-reference.com/players/b/bulmebr01/gamelog/2015/ list index out of range
# bunzty01 126 / 1100
# burakan01 127 / 1100
# burisad01 128 / 1100
# burmial01 129 / 1100
# burmial01 error in 2015 http://www.hockey-reference.com/players/b/burmial01/gamelog/2015/ list index out of range
# burnsbr01 130 / 1100
# burroal01 131 / 1100
# butlech01 132 / 1100
# byfugdu01 133 / 1100
# byronpa01 134 / 1100
# callary01 135 / 1100
# calvema01 136 / 1100
# cammami01 137 / 1100
# campban01 138 / 1100
# campbbr02 139 / 1100
# campbgr01 140 / 1100
# carcida01 141 / 1100
# careypa01 142 / 1100
# carlema01 143 / 1100
# carlsjo01 144 / 1100
# caronjo01 145 / 1100
# carpery01 146 / 1100
# carrda01 147 / 1100
# carrico01 148 / 1100
# carrico01 error in 2015 http://www.hockey-reference.com/players/c/carrico01/gamelog/2015/ list index out of range
# carrisa01 149 / 1100
# carteje01 150 / 1100
# cartery01 151 / 1100
# cecico01 152 / 1100
# chapumi01 153 / 1100
# charazd01 154 / 1100
# chiarbe01 155 / 1100
# chiasal01 156 / 1100
# chimeja01 157 / 1100
# chipcky01 158 / 1100
# chornta01 159 / 1100
# cizikca01 160 / 1100
# claesfr01 161 / 1100
# clarkma01 162 / 1100
# clarkda03 163 / 1100
# clearda01 164 / 1100
# clemmsc01 165 / 1100
# clendad01 166 / 1100
# clichma01 167 / 1100
# cliffky01 168 / 1100
# clitsgr01 169 / 1100
# clowery01 170 / 1100
# cluneri01 171 / 1100
# cluttca01 172 / 1100
# coburbr01 173 / 1100
# coglian01 174 / 1100
# colaica01 175 / 1100
# colbojo01 176 / 1100
# coleer01 177 / 1100
# coleia01 178 / 1100
# collise02 179 / 1100
# comeabl01 180 / 1100
# conacco01 181 / 1100
# condomi01 182 / 1100
# condrer01 183 / 1100
# connake01 184 / 1100
# connech01 185 / 1100
# connobr01 186 / 1100
# cookema01 187 / 1100
# coppan01 188 / 1100
# cormipa01 189 / 1100
# corrafr01 190 / 1100
# cousini01 191 / 1100
# coutulo01 192 / 1100
# coutuse01 193 / 1100
# cowenja01 194 / 1100
# coylech01 195 / 1100
# crackad01 196 / 1100
# craigry01 197 / 1100
# crawfco01 198 / 1100
# crombbj01 199 / 1100
# crosbsi01 200 / 1100
# crossto01 201 / 1100
# cullema01 202 / 1100
# cumisky01 203 / 1100
# cunnicr01 204 / 1100
# curryjo01 205 / 1100
# damigje01 206 / 1100
# dahlbkl01 207 / 1100
# daleytr01 208 / 1100
# dalpeza01 209 / 1100
# danauph01 210 / 1100
# danoma01 211 / 1100
# darlisc01 212 / 1100
# datsypa01 213 / 1100
# dauphla01 214 / 1100
# davidbr01 215 / 1100
# dehaaca01 216 / 1100
# delarja01 217 / 1100
# defazbr01 218 / 1100
# dekeyda01 219 / 1100
# delzomi01 220 / 1100
# demeldy01 221 / 1100
# demerja01 222 / 1100
# deshada01 223 / 1100
# desjaan01 224 / 1100
# deslani01 225 / 1100
# desprsi01 226 / 1100
# digiuph01 227 / 1100
# diazra01 228 / 1100
# dillobr01 229 / 1100
# doansh01 230 / 1100
# domima01 231 / 1100
# dominlo01 232 / 1100
# donovma01 233 / 1100
# donskjo01 234 / 1100
# dorsede01 235 / 1100
# doughdr01 236 / 1100
# downist01 237 / 1100
# draisle01 238 / 1100
# driedch01 239 / 1100
# drouijo01 240 / 1100
# dubinbr01 241 / 1100
# dubnyde01 242 / 1100
# duchema01 243 / 1100
# duclaan01 244 / 1100
# dumbama01 245 / 1100
# dumonga01 246 / 1100
# dumoubr01 247 / 1100
# dupuipa01 248 / 1100
# dwyerpa01 249 / 1100
# dzingry01 250 / 1100
# dziurda01 251 / 1100
# dziurda01 error in 2015 http://www.hockey-reference.com/players/d/dziurda01/gamelog/2015/ list index out of range
# eakinco01 252 / 1100
# eavespa01 253 / 1100
# ebbetan01 254 / 1100
# eberljo01 255 / 1100
# edleral01 256 / 1100
# edmunjo01 257 / 1100
# ehlerni01 258 / 1100
# ehrhoch01 259 / 1100
# eicheja01 260 / 1100
# ekblaaa01 261 / 1100
# ekholma01 262 / 1100
# ekmanol01 263 / 1100
# eliaspa01 264 / 1100
# ellerla01 265 / 1100
# ellerke01 266 / 1100
# elliobr01 267 / 1100
# elliost01 268 / 1100
# ellisda01 269 / 1100
# ellisma01 270 / 1100
# ellisry01 271 / 1100
# emelial01 272 / 1100
# emeryra01 273 / 1100
# engelde01 274 / 1100
# ennisty01 275 / 1100
# enrotjh01 276 / 1100
# enstrto01 277 / 1100
# eratma01 278 / 1100
# ericsjo01 279 / 1100
# erikslo01 280 / 1100
# erixoti01 281 / 1100
# etemem01 282 / 1100
# everbde01 283 / 1100
# fabbrro01 284 / 1100
# faksara01 285 / 1100
# falkju01 286 / 1100
# farnhbo01 287 / 1100
# fastje01 288 / 1100
# fasthvi01 289 / 1100
# faulkju01 290 / 1100
# faynema01 291 / 1100
# fedunta01 292 / 1100
# fehrer01 293 / 1100
# ferenan01 294 / 1100
# ferlami01 295 / 1100
# ferlibr01 296 / 1100
# ferrala01 297 / 1100
# fialake01 298 / 1100
# fiddlve01 299 / 1100
# filppva01 300 / 1100
# fishemi01 301 / 1100
# fistrma01 302 / 1100
# fleisto01 303 / 1100
# fleurma01 304 / 1100
# flynnbr01 305 / 1100
# foligma01 306 / 1100
# foligni01 307 / 1100
# folinch01 308 / 1100
# fontaju01 309 / 1100
# forbode01 310 / 1100
# forsban01 311 / 1100
# forsbfi01 312 / 1100
# fowleca01 313 / 1100
# fransco01 314 / 1100
# franzjo01 315 / 1100
# fraseco01 316 / 1100
# frasema01 317 / 1100
# frasema02 318 / 1100
# frattma01 319 / 1100
# fribema01 320 / 1100
# froesby01 321 / 1100
# frolimi01 322 / 1100
# gaborma01 323 / 1100
# gabriku01 324 / 1100
# gagnesi01 325 / 1100
# gagnesa01 326 / 1100
# galchal01 327 / 1100
# galiatj01 328 / 1100
# galiest01 329 / 1100
# gallabr01 330 / 1100
# garbury01 331 / 1100
# gardija01 332 / 1100
# garrija01 333 / 1100
# gaudety01 334 / 1100
# gaudrjo01 335 / 1100
# gauncbr01 336 / 1100
# gaustpa01 337 / 1100
# gazdilu01 338 / 1100
# geliner01 339 / 1100
# gerbena01 340 / 1100
# getzlry01 341 / 1100
# gibbobr02 342 / 1100
# gibsoch01 343 / 1100
# gibsojo02 344 / 1100
# gilbeto01 345 / 1100
# giontbr01 346 / 1100
# giontst01 347 / 1100
# giordma01 348 / 1100
# girarda01 349 / 1100
# girgeze01 350 / 1100
# giroucl01 351 / 1100
# glassta01 352 / 1100
# gleasti01 353 / 1100
# glenccu01 354 / 1100
# glendlu01 355 / 1100
# gocma01 356 / 1100
# goldoni01 357 / 1100
# goligal01 358 / 1100
# golouco01 359 / 1100
# gomezsc01 360 / 1100
# gonchse01 361 / 1100
# goodrba01 362 / 1100
# gordobo01 363 / 1100
# gorgejo01 364 / 1100
# gormlbr01 365 / 1100
# gostish01 366 / 1100
# gourdya01 367 / 1100
# grabnmi01 368 / 1100
# grabomi01 369 / 1100
# gragnma01 370 / 1100
# gragnma01 error in 2015 http://www.hockey-reference.com/players/g/gragnma01/gamelog/2015/ list index out of range
# granbpe01 371 / 1100
# granlma01 372 / 1100
# granlmi01 373 / 1100
# grantde01 374 / 1100
# grantde01 error in 2015 http://www.hockey-reference.com/players/g/grantde01/gamelog/2015/ list index out of range
# graovty01 375 / 1100
# greenmi03 376 / 1100
# greenan01 377 / 1100
# greenma01 378 / 1100
# greenco01 379 / 1100
# greisth01 380 / 1100
# grenial01 381 / 1100
# griffse01 382 / 1100
# grigomi01 383 / 1100
# grimaro01 384 / 1100
# grosetr01 385 / 1100
# grossni01 386 / 1100
# grubaph01 387 / 1100
# grybaer01 388 / 1100
# gudasra01 389 / 1100
# gudbrer01 390 / 1100
# gudlekr01 391 / 1100
# gudlekr01 error in 2015 http://www.hockey-reference.com/players/g/gudlekr01/gamelog/2015/ list index out of range
# guenina01 392 / 1100
# gunnaca01 393 / 1100
# gustaer02 394 / 1100
# gustajo01 395 / 1100
# hackema01 396 / 1100
# hagelca01 397 / 1100
# hainsro01 398 / 1100
# halakja01 399 / 1100
# haleymi01 400 / 1100
# halisma01 401 / 1100
# hallta02 402 / 1100
# hamhuda01 403 / 1100
# hamilcu01 404 / 1100
# hamildo01 405 / 1100
# hamilfr01 406 / 1100
# hamilry01 407 / 1100
# hammoan01 408 / 1100
# hamontr01 409 / 1100
# hanifno01 410 / 1100
# hannasc01 411 / 1100
# hannima01 412 / 1100
# hanseja01 413 / 1100
# hanzama01 414 / 1100
# harrisc01 415 / 1100
# harrija01 416 / 1100
# harrope01 417 / 1100
# hartmry01 418 / 1100
# hartnsc01 419 / 1100
# haulaer01 420 / 1100
# havlama01 421 / 1100
# hayeser01 422 / 1100
# hayesji01 423 / 1100
# hayeske01 424 / 1100
# heatlda01 425 / 1100
# hedmavi01 426 / 1100
# hejdaja01 427 / 1100
# helgese01 428 / 1100
# hellbma01 429 / 1100
# hellbma01 error in 2015 http://www.hockey-reference.com/players/h/hellbma01/gamelog/2015/ list index out of range
# helleco01 430 / 1100
# helmda01 431 / 1100
# hemskal01 432 / 1100
# hendrma01 433 / 1100
# henriad01 434 / 1100
# hertlto01 435 / 1100
# hicketh01 436 / 1100
# higgich01 437 / 1100
# hilleja01 438 / 1100
# hillejo01 439 / 1100
# hinosvi01 440 / 1100
# hishojo01 441 / 1100
# hjalmni01 442 / 1100
# hodgmju01 443 / 1100
# hodgsco01 444 / 1100
# hoffmmi02 445 / 1100
# holdeni01 446 / 1100
# hollape01 447 / 1100
# hollobu01 448 / 1100
# holtbbr01 449 / 1100
# holzeko01 450 / 1100
# horcosh01 451 / 1100
# hornqpa01 452 / 1100
# horvabo01 453 / 1100
# hossama01 454 / 1100
# howarja02 455 / 1100
# howdequ01 456 / 1100
# howdequ01 error in 2015 http://www.hockey-reference.com/players/h/howdequ01/gamelog/2015/ list index out of range
# hrabara01 457 / 1100
# huberjo01 458 / 1100
# hudleji01 459 / 1100
# hudonch01 460 / 1100
# huntbr01 461 / 1100
# hunwima01 462 / 1100
# hutchmi01 463 / 1100
# huttobe01 464 / 1100
# huttoca01 465 / 1100
# iginlja01 466 / 1100
# irwinma01 467 / 1100
# jackmba01 468 / 1100
# jackmti01 469 / 1100
# jagrja01 470 / 1100
# janmama02 471 / 1100
# jarnkca01 472 / 1100
# jaskidm01 473 / 1100
# jeffrdu01 474 / 1100
# jeffrdu01 error in 2015 http://www.hockey-reference.com/players/j/jeffrdu01/gamelog/2015/ list index out of range
# jennebo01 475 / 1100
# jenseni01 476 / 1100
# joensje01 477 / 1100
# johanry01 478 / 1100
# johanma03 479 / 1100
# johnsch02 480 / 1100
# johnser01 481 / 1100
# johnsja02 482 / 1100
# johnsty01 483 / 1100
# jokinju01 484 / 1100
# jokinol01 485 / 1100
# jokipjy01 486 / 1100
# jonesbl01 487 / 1100
# jonesda01 488 / 1100
# jonesma02 489 / 1100
# jonesse01 490 / 1100
# joorijo01 491 / 1100
# jordami01 492 / 1100
# josefja01 493 / 1100
# josiro01 494 / 1100
# jurcoto01 495 / 1100
# kadrina01 496 / 1100
# kaletpa01 497 / 1100
# kalinse01 498 / 1100
# kampfst01 499 / 1100
# kaneev01 500 / 1100
# kanepa01 501 / 1100
# karlser01 502 / 1100
# karlsme01 503 / 1100
# karlswi01 504 / 1100
# kassiza01 505 / 1100
# keithdu01 506 / 1100
# kellych01 507 / 1100
# kemppjo01 508 / 1100
# keninro01 509 / 1100
# kennety01 510 / 1100
# keranmi01 511 / 1100
# kerota01 512 / 1100
# keslery01 513 / 1100
# kesseph01 514 / 1100
# khairju01 515 / 1100
# khokhal01 516 / 1100
# khudoan01 517 / 1100
# killoal01 518 / 1100
# kindlja01 519 / 1100
# kingdw01 520 / 1100
# kinkake01 521 / 1100
# klefbos01 522 / 1100
# kleinke01 523 / 1100
# klingca01 524 / 1100
# klingjo01 525 / 1100
# klinkro01 526 / 1100
# knighco01 527 / 1100
# koekksl01 528 / 1100
# koivumi01 529 / 1100
# komarle01 530 / 1100
# kopecto01 531 / 1100
# kopitan01 532 / 1100
# korpila01 533 / 1100
# korpijo01 534 / 1100
# kostkmi01 535 / 1100
# kozunbr01 536 / 1100
# kreidch01 537 / 1100
# krejcda01 538 / 1100
# kronwni01 539 / 1100
# krugto01 540 / 1100
# krugema01 541 / 1100
# kucheni01 542 / 1100
# kuempda01 543 / 1100
# kuhnhto01 544 / 1100
# kulakbr01 545 / 1100
# kulemni01 546 / 1100
# kulikdm01 547 / 1100
# kunitch01 548 / 1100
# kuzneev01 549 / 1100
# labarja01 550 / 1100
# lacked01 551 / 1100
# laddan01 552 / 1100
# laichbr01 553 / 1100
# landean01 554 / 1100
# landega01 555 / 1100
# lapiema01 556 / 1100
# larkidy01 557 / 1100
# larssad01 558 / 1100
# larssjo02 559 / 1100
# lashobr01 560 / 1100
# lattami01 561 / 1100
# laughsc01 562 / 1100
# lauriol01 563 / 1100
# lazarcu01 564 / 1100
# lecavvi01 565 / 1100
# leddyni01 566 / 1100
# leean01 567 / 1100
# legwada01 568 / 1100
# lehnero01 569 / 1100
# lehtejo01 570 / 1100
# lehtoka01 571 / 1100
# leierta01 572 / 1100
# leivojo01 573 / 1100
# leopojo01 574 / 1100
# lergbr01 575 / 1100
# lessilu01 576 / 1100
# letankr01 577 / 1100
# letesma01 578 / 1100
# lewistr01 579 / 1100
# lilesjo01 580 / 1100
# lindban01 581 / 1100
# lindbos02 582 / 1100
# lindbma01 583 / 1100
# lindbpe02 584 / 1100
# lindees01 585 / 1100
# lindhel01 586 / 1100
# lindhha01 587 / 1100
# lindsjo01 588 / 1100
# liponj.01 589 / 1100
# littlbr01 590 / 1100
# lovejbe01 591 / 1100
# loweke02 592 / 1100
# lowryad01 593 / 1100
# lucicmi01 594 / 1100
# lundqhe01 595 / 1100
# luongro01 596 / 1100
# lupuljo01 597 / 1100
# maattol01 598 / 1100
# macarcl01 599 / 1100
# macdoan01 600 / 1100
# mackede01 601 / 1100
# mackina01 602 / 1100
# macwian01 603 / 1100
# makaran01 604 / 1100
# malhoma01 605 / 1100
# malkiev01 606 / 1100
# malonbr01 607 / 1100
# malonry01 608 / 1100
# mannibr01 609 / 1100
# mansojo01 610 / 1100
# marchbr03 611 / 1100
# marchal01 612 / 1100
# marinma01 613 / 1100
# markoan01 614 / 1100
# marksja02 615 / 1100
# marlepa01 616 / 1100
# maroopa01 617 / 1100
# martima02 618 / 1100
# martipa01 619 / 1100
# martial01 620 / 1100
# martijo01 621 / 1100
# martian01 622 / 1100
# mashibr01 623 / 1100
# mashibr01 error in 2015 http://www.hockey-reference.com/players/m/mashibr01/gamelog/2015/ list index out of range
# masonst01 624 / 1100
# mattest02 625 / 1100
# matthsh01 626 / 1100
# mayfisc01 627 / 1100
# mazanma01 628 / 1100
# mcbaija02 629 / 1100
# mccabja01 630 / 1100
# mccanja01 631 / 1100
# mccarmi01 632 / 1100
# mccarjo01 633 / 1100
# mccarjo01 error in 2015 http://www.hockey-reference.com/players/m/mccarjo01/gamelog/2015/ list index out of range
# mccleja01 634 / 1100
# mccolth01 635 / 1100
# mccorco01 636 / 1100
# mccorma01 637 / 1100
# mcdavco01 638 / 1100
# mcdonry01 639 / 1100
# mcdonco01 640 / 1100
# mcelhcu01 641 / 1100
# mcginbr01 642 / 1100
# mcginja01 643 / 1100
# mcginty01 644 / 1100
# mcgrabr01 645 / 1100
# mcilrdy01 646 / 1100
# mckeggr01 647 / 1100
# mckenmi01 648 / 1100
# mckencu01 649 / 1100
# mcleoco01 650 / 1100
# mcmilbr01 651 / 1100
# mcnabbr01 652 / 1100
# mcneima01 653 / 1100
# mcquaad01 654 / 1100
# medveev01 655 / 1100
# megnaja01 656 / 1100
# merrijo01 657 / 1100
# merscmi01 658 / 1100
# meszaan01 659 / 1100
# methoma01 660 / 1100
# michami01 661 / 1100
# michazb01 662 / 1100
# millean01 663 / 1100
# milleco02 664 / 1100
# milledr01 665 / 1100
# millejt01 666 / 1100
# milleke03 667 / 1100
# millery01 668 / 1100
# mitchjo01 669 / 1100
# mitchto01 670 / 1100
# mitchwi01 671 / 1100
# moentr01 672 / 1100
# monahse01 673 / 1100
# montoal01 674 / 1100
# mooredo01 675 / 1100
# moorejo01 676 / 1100
# morinje01 677 / 1100
# morintr01 678 / 1100
# morrobr01 679 / 1100
# morrojo02 680 / 1100
# mossda01 681 / 1100
# mouilka01 682 / 1100
# moulsma01 683 / 1100
# mrazepe01 684 / 1100
# muellch01 685 / 1100
# muellmi01 686 / 1100
# murphco02 687 / 1100
# murphry01 688 / 1100
# murrama02 689 / 1100
# murrary01 690 / 1100
# musilda01 691 / 1100
# muzzija01 692 / 1100
# myersty01 693 / 1100
# nabokev01 694 / 1100
# namesvl01 695 / 1100
# nashri01 696 / 1100
# nashri02 697 / 1100
# nealja01 698 / 1100
# neilch01 699 / 1100
# nelsobr01 700 / 1100
# nemetpa01 701 / 1100
# nessaa01 702 / 1100
# nessaa01 error in 2015 http://www.hockey-reference.com/players/n/nessaa01/gamelog/2015/ list index out of range
# nesteni01 703 / 1100
# nestran01 704 / 1100
# neuvimi01 705 / 1100
# nichuva01 706 / 1100
# niedeni01 707 / 1100
# nielsfr01 708 / 1100
# niemian02 709 / 1100
# nietoma01 710 / 1100
# nikitni01 711 / 1100
# nilssan01 712 / 1100
# nilssan01 error in 2015 http://www.hockey-reference.com/players/n/nilssan01/gamelog/2015/ list index out of range
# niskama01 713 / 1100
# noesest01 714 / 1100
# nolanjo01 715 / 1100
# nordsjo02 716 / 1100
# nosekto01 717 / 1100
# nugenry01 718 / 1100
# nurseda01 719 / 1100
# nyquigu01 720 / 1100
# nystrer01 721 / 1100
# obrieji01 722 / 1100
# obrieji01 error in 2015 http://www.hockey-reference.com/players/o/obrieji01/gamelog/2015/ list index out of range
# obrieli01 723 / 1100
# obriesh01 724 / 1100
# oconnma01 725 / 1100
# odeller01 726 / 1100
# oneilbr01 727 / 1100
# oreilca01 728 / 1100
# oreilca01 error in 2015 http://www.hockey-reference.com/players/o/oreilca01/gamelog/2015/ list index out of range
# oreilry01 729 / 1100
# oduyajo01 730 / 1100
# oestejo01 731 / 1100
# okposky01 732 / 1100
# oleksja01 733 / 1100
# oleksst01 734 / 1100
# olofsgu01 735 / 1100
# olsendy01 736 / 1100
# orlovdm01 737 / 1100
# orlovdm01 error in 2015 http://www.hockey-reference.com/players/o/orlovdm01/gamelog/2015/ list index out of range
# orpikbr01 738 / 1100
# orrco01 739 / 1100
# ortiojo01 740 / 1100
# oshietj01 741 / 1100
# ottst01 742 / 1100
# ouellxa01 743 / 1100
# ovechal01 744 / 1100
# paajama01 745 / 1100
# pacioma01 746 / 1100
# pageaje01 747 / 1100
# paillda01 748 / 1100
# pakarii01 749 / 1100
# palaton01 750 / 1100
# paliomi01 751 / 1100
# palmiky01 752 / 1100
# panarar01 753 / 1100
# panikri01 754 / 1100
# paquece01 755 / 1100
# parayco01 756 / 1100
# pardyad01 757 / 1100
# parenpi01 758 / 1100
# parisza01 759 / 1100
# pastrda01 760 / 1100
# patergr01 761 / 1100
# pavelon01 762 / 1100
# paveljo01 763 / 1100
# pearsta01 764 / 1100
# pedanan01 765 / 1100
# pelecad01 766 / 1100
# pelusan01 767 / 1100
# percyst01 768 / 1100
# perrema01 769 / 1100
# perroda01 770 / 1100
# perryco01 771 / 1100
# pescebr01 772 / 1100
# petanni01 773 / 1100
# peterju01 774 / 1100
# petroal01 775 / 1100
# petryje01 776 / 1100
# phanedi01 777 / 1100
# phillch02 778 / 1100
# pickaca01 779 / 1100
# pietral01 780 / 1100
# pinizst01 781 / 1100
# pirribr01 782 / 1100
# piskujo01 783 / 1100
# pitlity01 784 / 1100
# plekato01 785 / 1100
# plotnse01 786 / 1100
# poiriem01 787 / 1100
# polakro01 788 / 1100
# pominja01 789 / 1100
# portech01 790 / 1100
# porteke01 791 / 1100
# porteke01 error in 2015 http://www.hockey-reference.com/players/p/porteke01/gamelog/2015/ list index out of range
# postmpa01 792 / 1100
# potteco01 793 / 1100
# poulike01 794 / 1100
# poulibe01 795 / 1100
# poulide01 796 / 1100
# priceca01 797 / 1100
# princsh01 798 / 1100
# prossna01 799 / 1100
# proutda01 800 / 1100
# prustbr01 801 / 1100
# puempma01 802 / 1100
# pulkkte01 803 / 1100
# purcete01 804 / 1100
# pysykma01 805 / 1100
# quickjo01 806 / 1100
# quincky01 807 / 1100
# raantan01 808 / 1100
# rafflmi01 809 / 1100
# rakelri01 810 / 1100
# ramagjo01 811 / 1100
# ramoka01 812 / 1100
# randety01 813 / 1100
# ranfobr01 814 / 1100
# rantami01 815 / 1100
# rasktu01 816 / 1100
# raskvi01 817 / 1100
# rasmude01 818 / 1100
# rattity01 819 / 1100
# raymoma01 820 / 1100
# readma01 821 / 1100
# reavery01 822 / 1100
# redmoza01 823 / 1100
# reesedy01 824 / 1100
# regehro01 825 / 1100
# reginpe01 826 / 1100
# reillmi01 827 / 1100
# reimeja01 828 / 1100
# reinhgr01 829 / 1100
# reinhma01 830 / 1100
# reinhsa01 831 / 1100
# rendubo01 832 / 1100
# ribeimi01 833 / 1100
# richabr01 834 / 1100
# richami02 835 / 1100
# richabr02 836 / 1100
# riedeto01 837 / 1100
# riellmo01 838 / 1100
# rinalza01 839 / 1100
# rinnepe01 840 / 1100
# rissara01 841 / 1100
# ristora01 842 / 1100
# ritchbr01 843 / 1100
# ritchni01 844 / 1100
# robakco01 845 / 1100
# robidst01 846 / 1100
# robinbo01 847 / 1100
# roussan01 848 / 1100
# royde01 849 / 1100
# rozsimi01 850 / 1100
# ruhwech01 851 / 1100
# rundbda01 852 / 1100
# russekr01 853 / 1100
# rustbr01 854 / 1100
# ruututu01 855 / 1100
# ryanbo01 856 / 1100
# rycheke01 857 / 1100
# rydermi01 858 / 1100
# rynnaju01 859 / 1100
# saadbr01 860 / 1100
# salommi01 861 / 1100
# salvabr01 862 / 1100
# samuehe01 863 / 1100
# samueph01 864 / 1100
# santomi01 865 / 1100
# sarosju01 866 / 1100
# savarda01 867 / 1100
# sbisalu01 868 / 1100
# scandma01 869 / 1100
# scevico01 870 / 1100
# schalti01 871 / 1100
# scheima01 872 / 1100
# schenbr01 873 / 1100
# schenlu01 874 / 1100
# schilca01 875 / 1100
# schleda01 876 / 1100
# schmina01 877 / 1100
# schneco01 878 / 1100
# schrojo01 879 / 1100
# schulje02 880 / 1100
# schulju01 881 / 1100
# schulni01 882 / 1100
# schwaja01 883 / 1100
# scottjo01 884 / 1100
# scrivbe01 885 / 1100
# scudero01 886 / 1100
# seabrbr01 887 / 1100
# sedinda01 888 / 1100
# sedinhe01 889 / 1100
# seguity01 890 / 1100
# seidede01 891 / 1100
# sekacji01 892 / 1100
# sekeran01 893 / 1100
# seminal01 894 / 1100
# sestiti01 895 / 1100
# sestito01 896 / 1100
# setogde01 897 / 1100
# severda01 898 / 1100
# sgarbmi01 899 / 1100
# sharppa01 900 / 1100
# shattke01 901 / 1100
# shawan01 902 / 1100
# shawlo01 903 / 1100
# sheahri01 904 / 1100
# shearco01 905 / 1100
# sheppja01 906 / 1100
# shinkhu01 907 / 1100
# shinnbr01 908 / 1100
# shorede01 909 / 1100
# shoredr01 910 / 1100
# shoreni01 911 / 1100
# shuggju01 912 / 1100
# siemedu01 913 / 1100
# silfvja01 914 / 1100
# sillza01 915 / 1100
# simmowa01 916 / 1100
# sislomi01 917 / 1100
# sissoco01 918 / 1100
# sissoco01 error in 2015 http://www.hockey-reference.com/players/s/sissoco01/gamelog/2015/ list index out of range
# skapsma01 919 / 1100
# skillja01 920 / 1100
# skinnje01 921 / 1100
# skjeibr01 922 / 1100
# slateji01 923 / 1100
# slavija01 924 / 1100
# slepyan01 925 / 1100
# smidla01 926 / 1100
# smithbe01 927 / 1100
# smithbr05 928 / 1100
# smithco01 929 / 1100
# smithcr01 930 / 1100
# smithmi01 931 / 1100
# smithre01 932 / 1100
# smithtr01 933 / 1100
# smithza01 934 / 1100
# smithde06 935 / 1100
# soderca01 936 / 1100
# spalini01 937 / 1100
# sparkga01 938 / 1100
# spezzja01 939 / 1100
# spoonry01 940 / 1100
# spronda01 941 / 1100
# spurgja01 942 / 1100
# stdenfr01 943 / 1100
# stlouma01 944 / 1100
# staaler01 945 / 1100
# staaljo01 946 / 1100
# staalma01 947 / 1100
# staffdr01 948 / 1100
# stajama01 949 / 1100
# stalbvi01 950 / 1100
# staloal01 951 / 1100
# stamkst01 952 / 1100
# stantry01 953 / 1100
# stastpa01 954 / 1100
# steenal01 955 / 1100
# stemple01 956 / 1100
# stepade01 957 / 1100
# stephch02 958 / 1100
# stewach02 959 / 1100
# stollja01 960 / 1100
# stollka01 961 / 1100
# stonema01 962 / 1100
# stonemi01 963 / 1100
# stonecl01 964 / 1100
# stracty01 965 / 1100
# straibr01 966 / 1100
# strakpe01 967 / 1100
# stralan01 968 / 1100
# streebe01 969 / 1100
# streima01 970 / 1100
# stromry01 971 / 1100
# stuarbr02 972 / 1100
# stuarma01 973 / 1100
# subbama01 974 / 1100
# subbapk01 975 / 1100
# summech01 976 / 1100
# sundqos01 977 / 1100
# sustran01 978 / 1100
# suterry01 979 / 1100
# suttebr03 980 / 1100
# suttebr04 981 / 1100
# suttebr05 982 / 1100
# svedbni01 983 / 1100
# svedbvi01 984 / 1100
# szwarjo01 985 / 1100
# talboca01 986 / 1100
# talboma01 987 / 1100
# tanevch01 988 / 1100
# tangrer01 989 / 1100
# tangual01 990 / 1100
# taormma01 991 / 1100
# taormma01 error in 2015 http://www.hockey-reference.com/players/t/taormma01/gamelog/2015/ list index out of range
# tarasvl01 992 / 1100
# tarasda01 993 / 1100
# tatarto01 994 / 1100
# tavarjo01 995 / 1100
# tennyma01 996 / 1100
# teravte01 997 / 1100
# terrych01 998 / 1100
# theodsh01 999 / 1100
# thomach01 1000 / 1100
# thompna01 1001 / 1100
# thomppa02 1002 / 1100
# thorbch01 1003 / 1100
# thornjo01 1004 / 1100
# thornsh01 1005 / 1100
# tiernch01 1006 / 1100
# tikhovi01 1007 / 1100
# tikhovi01 error in 2015 http://www.hockey-reference.com/players/t/tikhovi01/gamelog/2015/ list index out of range
# timonki01 1008 / 1100
# tinorja01 1009 / 1100
# tlustji01 1010 / 1100
# toewsjo01 1011 / 1100
# toffoty01 1012 / 1100
# tokardu01 1013 / 1100
# tootojo01 1014 / 1100
# trochvi01 1015 / 1100
# troppco01 1016 / 1100
# trotmza01 1017 / 1100
# troubja01 1018 / 1100
# turriky01 1019 / 1100
# tyrelda01 1020 / 1100
# tyutife01 1021 / 1100
# uherdo01 1022 / 1100
# ullmali01 1023 / 1100
# umberrj01 1024 / 1100
# upshasc01 1025 / 1100
# vandeda01 1026 / 1100
# vanrija01 1027 / 1100
# vanritr01 1028 / 1100
# vandech01 1029 / 1100
# vanekth01 1030 / 1100
# varlasi01 1031 / 1100
# varonph01 1032 / 1100
# vasilan02 1033 / 1100
# vatansa01 1034 / 1100
# vatrafr01 1035 / 1100
# veillst01 1036 / 1100
# vermean01 1037 / 1100
# vermijo01 1038 / 1100
# verstkr01 1039 / 1100
# veyli01 1040 / 1100
# vincoto01 1041 / 1100
# virtaja01 1042 / 1100
# visnolu01 1043 / 1100
# vitaljo01 1044 / 1100
# vlasima01 1045 / 1100
# volchan01 1046 / 1100
# volpaaa01 1047 / 1100
# voracja01 1048 / 1100
# voynovi01 1049 / 1100
# vrbatra01 1050 / 1100
# wagnech01 1051 / 1100
# wardca01 1052 / 1100
# wardjo02 1053 / 1100
# warsoda01 1054 / 1100
# watsoau01 1055 / 1100
# watsoau01 error in 2015 http://www.hockey-reference.com/players/w/watsoau01/gamelog/2015/ list index out of range
# wealjo01 1056 / 1100
# weavemi01 1057 / 1100
# webermi01 1058 / 1100
# webersh01 1059 / 1100
# weberya01 1060 / 1100
# weiseda01 1061 / 1100
# weissst01 1062 / 1100
# welshje01 1063 / 1100
# welshje01 error in 2015 http://www.hockey-reference.com/players/w/welshje01/gamelog/2015/ list index out of range
# wennbal01 1064 / 1100
# wheelbl01 1065 / 1100
# whitery01 1066 / 1100
# whitnjo01 1067 / 1100
# widemch01 1068 / 1100
# widemde01 1069 / 1100
# wiercpa01 1070 / 1100
# willro01 1071 / 1100
# williju01 1072 / 1100
# wilsoco01 1073 / 1100
# wilsoga01 1074 / 1100
# wilsory01 1075 / 1100
# wilsosc01 1076 / 1100
# wilsoto01 1077 / 1100
# wingeto01 1078 / 1100
# winnida01 1079 / 1100
# wisnija01 1080 / 1100
# witkolu01 1081 / 1100
# wolfda01 1082 / 1100
# woodsbr01 1083 / 1100
# wothety01 1084 / 1100
# yakimbo01 1085 / 1100
# yakupna01 1086 / 1100
# yandlke01 1087 / 1100
# zadorni01 1088 / 1100
# zajactr01 1089 / 1100
# zalewmi01 1090 / 1100
# zalewmi01 error in 2015 http://www.hockey-reference.com/players/z/zalewmi01/gamelog/2015/ list index out of range
# zatkoje01 1091 / 1100
# zeppro01 1092 / 1100
# zettehe01 1093 / 1100
# zibanmi01 1094 / 1100
# zidlima01 1095 / 1100
# zolniha01 1096 / 1100
# zubruda01 1097 / 1100
# zuccama01 1098 / 1100
# zuckeja01 1099 / 1100
# Time Elapsed: 3574.45561886

# %%
global_stats.to_csv('/Users/andingo/Desktop/NHL/data/global_stats.csv')
goalie_stats.to_csv('/Users/andingo/Desktop/NHL/data/goalie_stats.csv')

# %%
global_stats = pd.read_csv('/Users/andingo/Desktop/NHL/data/global_stats.csv')
goalie_stats = pd.read_csv('/Users/andingo/Desktop/NHL/data/goalie_stats.csv')
global_stats.Date = [datetime.datetime.strptime(x, '%Y-%m-%d').date() for x in global_stats.Date]
goalie_stats.Date = [datetime.datetime.strptime(x, '%Y-%m-%d').date() for x in goalie_stats.Date]

# %%
def fantasy_points(GL):
    gl = GL.copy()
    if 'GA' in gl.keys():
        gl['DK'] = 3*(gl['W/L']=='W') - gl.GA + .2*gl.SV + gl.SO
        gl['FD'] = gl.DK
    else:
        gl['DK'] = 3*gl.G + 2*gl.A + .5*gl.S + .5*gl.BLK + gl.GOAL_SH + gl.AST_SH + (1.5*(gl.G>=3) if 'HT' not in gl.keys() else 1.5*gl.HT)
        gl['FD'] = 3*gl.G + 2*gl.A + .5*gl.GOAL_PP + .5*gl.AST_PP + .4*gl.S + gl['+/-'] + .25*gl.PIM
    return gl

# %%
global_stats = fantasy_points(global_stats)

# %% [markdown]
# ## FanDuel

# %%
def get_pid(name, pl, **kwargs):
    I = pl.NAME == name
    if not any(I):
        raise Exception('%s not found' % name)
    for col, st in kwargs.iteritems():
        I = I & (pl[col] == st)
    if not any(I):
        raise Exception('%s not found with specifications %s' % (name, kwargs))
    return pl[I].PID.iloc[0]

# %%
fdpl = pd.read_csv('/Users/andingo/Desktop/NHL/PlayerLists/pl_fd_nhl_2016-02-11.csv')
fdpl['NAME'] = ['%s %s' % (f,l) for f,l in itertools.izip(fdpl['First Name'], fdpl['Last Name'])]
# fdpl['PID'] = [get_pid(NAME_CORRECTIONS[x], pl) if x in NAME_CORRECTIONS else get_pid(x, pl) for x in fdpl.NAME]

# for x in fdpl.NAME:
#     try:
#         get_pid(NAME_CORRECTIONS[x], pl) if x in NAME_CORRECTIONS else get_pid(x, pl)
#     except Exception, e:
#         print e.message
# Out:
# Anrew Miller not found
# Jakub Nakladal not found
# /Users/andingo/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:9: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6

# %%
NAME_CORRECTIONS = {
    'Alexander Ovechkin' : 'Alex Ovechkin',
    'Johnny Gaudreau' : 'John Gaudreau',
    'Jon Quick' : 'Jonathan Quick',
    "Matthew O'Connor" : "Matt O'Connor",
    'Cameron Talbot' : 'Cam Talbot',
    'Jacob Muzzin' : 'Jake Muzzin',
    'Samuel Bennett' : 'Sam Bennett',
    'Michael Ferland' : 'Micheal Ferland',
    'Pierre Parenteau' : 'P.A. Parenteau',
    'Viatcheslav Voynov' : 'Slava Voynov',
    'Alex Burmistrov' : 'Alexander Burmistrov',
    'Trevor Van Riemsdyk' : 'Trevor van Riemsdyk',
    'Dylan Demelo' : 'Dylan DeMelo',
    'Tobias Enstrom' : 'Toby Enstrom',
    'Chris Vande Velde' : 'Chris VandeVelde',
    'Joe Morrow' : 'Joseph Morrow',
    'Andew Miller' : 'Andrew Miller',
    'Phil Varone' : 'Philip Varone',
    'Richard Clune' : 'Rich Clune',
    'Max Talbot' : 'Maxime Talbot',
    'Yevgeni Medvedev' : 'Evgeny Medvedev',
}

# %%
pl[['Medvedev' in x for x in pl.NAME]].NAME
# pl[pl.NAME=='Arturs Kulda']
# Out:
# 6102    Andrei Medvedev
# 6103    Evgeny Medvedev
# Name: NAME, dtype: object

# %%
pl[pl.PID=='naklaja01']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BIRTHDAY, END_YEAR, HEIGHT, LEAGUE, NAME, PID, POS, START_YEAR, WEIGHT]
# Index: []
