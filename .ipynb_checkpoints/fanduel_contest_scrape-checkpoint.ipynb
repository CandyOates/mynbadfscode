# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from itertools import izip

# %%
class FanDuelScraper(object):
    def __init__(self):
        """Create a Firefox Browser to Scrape FanDuel Contest Data."""
        self.ff = webdriver.Firefox(firefox_profile=webdriver.FirefoxProfile('/Users/andingo/Library/Application Support/Firefox/Profiles/eual1qsf.PythonScripts'))
    
    def gotoURL(self, url):
        """Goto the contest url."""
        self.ff.get(url)
    
    def getPrizes(self):
        """Get a list of places and corresponding prizes. For prizes earned by a range of ranks,
        use the place of the lowest ranking position to win that prize."""
        elem = self.ff.find_element_by_class_name("toggle-show-prize-scoring")
        elem.click()
        places = []
        prizes = []
        for elem in self.ff.find_elements_by_tag_name('dl'):
            try:
                spl = elem.text.split('$')
                prize = float(spl[1].replace(',',''))
                place = int(spl[0].split(' - ')[-1][:-3])
#                 print '%6d\t%.2f' % (place, prize)
                places.append(place)
                prizes.append(prize)
            except Exception, e:
                print e.message
        elem = self.ff.find_element_by_class_name('live-prize-scoring-close')
        elem = elem.find_element_by_class_name('button')
        elem.click()
        return places, prizes
    
    def getLevels(self, places, prizes):
        page_num = 0
        d = dict(Prize=[], Score=[])
        for k, rk in enumerate(places):
            new_page_num = rk/10+int(rk % 10 != 0)
            if new_page_num != page_num:
                page_num = new_page_num
                elem = self.ff.find_element_by_class_name('paging-input')
                elem.send_keys('%s%d' % (10*Keys.BACKSPACE, page_num))
                time.sleep(2)
                winnings = map(lambda x: float(x.text[1:].replace(',','')), self.ff.find_elements_by_class_name('user-winnings'))
                scores = map(lambda x: float(x.text.replace(',','')), self.ff.find_elements_by_class_name('user-score'))
            ind = rk - (page_num - int(rk % 10 != 0))*10 + 10*int(rk % 10 == 0) - 1
            if prizes[k] != winnings[ind]:
                d['Prize'].append(prizes[k])
                d['Score'].append(scores[ind]+.01)
            d['Prize'].append(winnings[ind])
            d['Score'].append(scores[ind])
        #     print rk, prizes[k], winnings[ind], scores[ind]
        assert not any([d['Prize'][i] <= d['Prize'][i+1] for i in range(len(d['Prize'])-1)])
        return pd.DataFrame(d)
    
    def getGames(self):
        elems = self.ff.find_elements_by_class_name('live-fixture__team-code')
        return ['%s@%s' % (a.text,h.text) for a, h in izip(elems[::2], elems[1::2])]
    
    def exit(self):
        self.ff.quit()
        self.ff.close()

# %%
fds = FanDuelScraper()

# %%
url = 'https://www.fanduel.com/games/14647/contests/14647-22550651/scoring'
fds.gotoURL(url)
fds.getGames()
places, prizes = fds.getPrizes()
scores = fds.getLevels(places, prizes)
print 'P = ',scores.Prize.tolist()
print 'L = ',scores.Score.tolist()

# %%
import datetime
d = {
    datetime.date(2016, 2, 4) : 'https://www.fanduel.com/games/14608/contests/14608-22444314/scoring',
    datetime.date(2016, 2, 3) : 'https://www.fanduel.com/games/14597/contests/14597-22414605/scoring',
    datetime.date(2016, 2, 2) : 'https://www.fanduel.com/games/14586/contests/14586-22388706/scoring',
    datetime.date(2016, 2, 1) : 'https://www.fanduel.com/games/14579/contests/14579-22361721/scoring',
    datetime.date(2016, 1, 31) : 'https://www.fanduel.com/games/14571/contests/14571-22335833/scoring',
    datetime.date(2016, 1, 30) : 'https://www.fanduel.com/games/14566/contests/14566-22308069/scoring',
    datetime.date(2016, 1, 29) : 'https://www.fanduel.com/games/14555/contests/14555-22279380/scoring',
    datetime.date(2016, 1, 28) : 'https://www.fanduel.com/games/14547/contests/14547-22252783/scoring',
    datetime.date(2016, 1, 27) : 'https://www.fanduel.com/games/14538/contests/14538-22219116/scoring',
    datetime.date(2016, 1, 26) : 'https://www.fanduel.com/games/14527/contests/14527-22189406/scoring',
    datetime.date(2016, 1, 25) : 'https://www.fanduel.com/games/14519/contests/14519-22153110/scoring',
    datetime.date(2016, 1, 24) : 'https://www.fanduel.com/games/14513/contests/14513-22109355/scoring',
}

for date, url in d.iteritems():
    fds.gotoURL(url)
    places, prizes = fds.getPrizes()
    scores = fds.getLevels(places, prizes)
    print date
    print 'P = ',scores.Prize.tolist()
    print 'L = ',scores.Score.tolist()
# Out:
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-02-04
# P =  [10000.0, 4000.0, 5000.0, 4000.0, 2500.0, 4000.0, 1500.0, 4000.0, 1000.0, 4000.0, 750.0, 537.5, 500.0, 537.5, 400.0, 300.0, 200.0, 145.44999999999999, 150.0, 145.44999999999999, 100.0, 75.0, 50.0, 46.049999999999997, 40.0, 30.0, 26.25, 25.0, 20.710000000000001, 20.0, 16.879999999999999, 15.0, 12.33, 10.0, 8.0, 7.0, 6.3799999999999999, 5.0, 4.0, 3.5099999999999998, 3.0, 2.3999999999999999, 2.0, 0.11]
# L =  [389.31, 389.30000000000001, 389.31, 389.30000000000001, 389.31, 389.30000000000001, 389.31, 389.30000000000001, 389.31, 389.30000000000001, 388.70999999999998, 388.69999999999999, 388.70999999999998, 388.69999999999999, 384.0, 376.19999999999999, 375.61000000000001, 375.60000000000002, 375.61000000000001, 375.60000000000002, 374.89999999999998, 370.30000000000001, 369.00999999999999, 369.0, 366.19999999999999, 361.31, 361.30000000000001, 355.61000000000001, 355.60000000000002, 353.31, 353.30000000000001, 350.90999999999997, 350.89999999999998, 347.11000000000001, 347.10000000000002, 341.70999999999998, 341.69999999999999, 335.39999999999998, 330.11000000000001, 330.10000000000002, 319.81, 319.80000000000001, 304.90999999999997, 304.89999999999998]
# list index out of range
# invalid literal for float(): 75000 PRIZES
# list index out of range
# 2016-01-30
# P =  [6000.0, 1743.75, 3000.0, 1743.75, 2000.0, 1743.75, 1000.0, 1743.75, 750.0, 1743.75, 500.0, 1743.75, 400.0, 1743.75, 300.0, 1743.75, 250.0, 225.0, 200.0, 225.0, 150.0, 137.5, 100.0, 67.390000000000001, 75.0, 67.390000000000001, 50.0, 43.329999999999998, 40.0, 33.329999999999998, 30.0, 28.329999999999998, 25.0, 24.379999999999999, 20.0, 19.780000000000001, 15.0, 11.880000000000001, 10.0, 9.25, 7.0, 5.4199999999999999, 5.0, 4.8200000000000003, 3.0, 2.7599999999999998, 2.5, 1.9099999999999999]
# L =  [394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 394.00999999999999, 394.0, 391.90999999999997, 391.89999999999998, 391.90999999999997, 391.89999999999998, 390.90999999999997, 390.89999999999998, 390.31, 390.30000000000001, 390.31, 390.30000000000001, 386.61000000000001, 386.60000000000002, 383.31, 383.30000000000001, 380.90999999999997, 380.89999999999998, 379.90999999999997, 379.89999999999998, 378.40999999999997, 378.39999999999998, 374.50999999999999, 374.5, 370.70999999999998, 370.69999999999999, 365.50999999999999, 365.5, 354.70999999999998, 354.69999999999999, 341.81, 341.80000000000001, 328.50999999999999, 328.5]
# list index out of range
# invalid literal for float(): 75000 PRIZES
# list index out of range
# 2016-01-31
# P =  [6000.0, 3000.0, 2000.0, 1000.0, 750.0, 500.0, 400.0, 350.0, 300.0, 350.0, 250.0, 200.0, 175.0, 150.0, 125.0, 100.0, 75.0, 50.0, 75.0, 40.0, 32.5, 30.0, 25.0, 20.0, 17.0, 15.0, 12.0, 10.0, 7.0, 6.2300000000000004, 5.0, 4.9100000000000001, 3.0, 2.77, 2.5, 0.94999999999999996]
# L =  [354.39999999999998, 353.5, 353.39999999999998, 353.10000000000002, 351.80000000000001, 350.69999999999999, 349.00999999999999, 349.0, 349.00999999999999, 349.0, 347.80000000000001, 347.00999999999999, 347.0, 346.50999999999999, 346.5, 344.0, 342.69999999999999, 340.11000000000001, 340.10000000000002, 337.00999999999999, 337.0, 335.19999999999999, 332.0, 328.90999999999997, 328.89999999999998, 326.50999999999999, 326.5, 321.60000000000002, 316.40999999999997, 316.39999999999998, 303.81, 303.80000000000001, 290.11000000000001, 290.10000000000002, 278.11000000000001, 278.10000000000002]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-01-28
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 850.0, 1000.0, 850.0, 750.0, 850.0, 500.0, 850.0, 400.0, 300.0, 260.0, 200.0, 150.0, 100.0, 80.0, 75.0, 80.0, 50.0, 45.0, 40.0, 35.0, 30.0, 28.129999999999999, 25.0, 24.0, 20.0, 15.0, 13.75, 10.0, 7.1200000000000001, 7.0, 5.6699999999999999, 5.0, 4.6900000000000004, 4.0, 3.3300000000000001, 3.0, 2.0299999999999998, 2.0, 3.0]
# L =  [388.39999999999998, 384.10000000000002, 382.0, 379.61000000000001, 379.60000000000002, 379.61000000000001, 379.60000000000002, 379.61000000000001, 379.60000000000002, 379.61000000000001, 379.60000000000002, 375.69999999999999, 375.50999999999999, 375.5, 375.10000000000002, 373.60000000000002, 370.31, 370.30000000000001, 370.31, 370.30000000000001, 366.20999999999998, 366.19999999999999, 362.70999999999998, 362.69999999999999, 360.50999999999999, 360.5, 357.40999999999997, 357.39999999999998, 355.30000000000001, 352.50999999999999, 352.5, 348.40999999999997, 348.39999999999998, 343.00999999999999, 343.0, 337.90999999999997, 337.89999999999998, 334.00999999999999, 334.0, 322.61000000000001, 322.60000000000002, 301.50999999999999, 301.5]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-01-29
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1250.0, 1000.0, 1250.0, 750.0, 500.0, 400.0, 300.0, 250.0, 200.0, 150.0, 100.0, 75.0, 50.0, 40.0, 36.0, 30.0, 25.0, 21.32, 20.0, 18.0, 15.0, 12.5, 10.0, 8.7100000000000009, 7.0, 5.5, 5.0, 4.2400000000000002, 4.0, 3.0, 2.52, 2.0, 0.52000000000000002]
# L =  [353.19999999999999, 352.80000000000001, 352.19999999999999, 351.70999999999998, 351.69999999999999, 351.70999999999998, 351.69999999999999, 351.5, 349.19999999999999, 348.39999999999998, 347.11000000000001, 347.10000000000002, 346.39999999999998, 344.69999999999999, 344.19999999999999, 342.39999999999998, 339.39999999999998, 335.81, 335.80000000000001, 333.5, 330.81, 330.80000000000001, 329.11000000000001, 329.10000000000002, 326.40999999999997, 326.39999999999998, 323.81, 323.80000000000001, 319.40999999999997, 319.39999999999998, 314.00999999999999, 314.0, 309.30000000000001, 300.90999999999997, 300.89999999999998, 287.11000000000001, 287.10000000000002]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-01-26
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 200.0, 180.0, 150.0, 100.0, 75.0, 50.0, 40.0, 30.0, 27.5, 25.0, 23.75, 20.0, 17.5, 15.0, 11.94, 10.0, 7.8799999999999999, 7.0, 5.3499999999999996, 5.0, 4.5700000000000003, 4.0, 3.5800000000000001, 3.0, 2.98, 2.0, 1.6399999999999999]
# L =  [388.5, 384.69999999999999, 383.89999999999998, 383.60000000000002, 383.5, 382.60000000000002, 381.39999999999998, 378.80000000000001, 378.5, 377.70999999999998, 377.69999999999999, 377.39999999999998, 375.80000000000001, 374.80000000000001, 370.80000000000001, 366.89999999999998, 363.70999999999998, 363.69999999999999, 360.81, 360.80000000000001, 359.31, 359.30000000000001, 356.20999999999998, 356.19999999999999, 354.00999999999999, 354.0, 348.70999999999998, 348.69999999999999, 342.31, 342.30000000000001, 336.11000000000001, 336.10000000000002, 326.00999999999999, 326.0, 308.40999999999997, 308.39999999999998]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-01-27
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 200.0, 150.0, 100.0, 75.0, 50.0, 40.0, 30.0, 27.5, 25.0, 20.829999999999998, 20.0, 19.170000000000002, 15.0, 14.380000000000001, 10.0, 7.9000000000000004, 7.0, 5.1699999999999999, 5.0, 4.54, 4.0, 3.5499999999999998, 3.0, 2.8199999999999998, 2.0, 0.17999999999999999]
# L =  [371.69999999999999, 369.60000000000002, 362.60000000000002, 361.89999999999998, 361.39999999999998, 359.5, 358.39999999999998, 357.89999999999998, 357.0, 355.5, 353.39999999999998, 352.80000000000001, 350.5, 347.80000000000001, 343.69999999999999, 340.40999999999997, 340.39999999999998, 336.90999999999997, 336.89999999999998, 334.50999999999999, 334.5, 332.11000000000001, 332.10000000000002, 329.11000000000001, 329.10000000000002, 323.11000000000001, 323.10000000000002, 316.61000000000001, 316.60000000000002, 311.90999999999997, 311.89999999999998, 300.90999999999997, 300.89999999999998, 282.70999999999998, 282.69999999999999]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-02-03
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 200.0, 175.0, 150.0, 100.0, 75.0, 50.0, 40.0, 33.329999999999998, 30.0, 25.0, 21.670000000000002, 20.0, 18.329999999999998, 15.0, 12.73, 10.0, 8.0700000000000003, 7.0, 6.6699999999999999, 5.0, 4.6900000000000004, 4.0, 3.0299999999999998, 3.0, 2.96, 2.0, 0.77000000000000002]
# L =  [372.89999999999998, 372.5, 371.39999999999998, 371.0, 367.39999999999998, 366.39999999999998, 365.0, 361.69999999999999, 361.10000000000002, 360.31, 360.30000000000001, 359.10000000000002, 356.89999999999998, 355.39999999999998, 352.80000000000001, 349.40999999999997, 349.39999999999998, 346.0, 342.61000000000001, 342.60000000000002, 340.70999999999998, 340.69999999999999, 338.00999999999999, 338.0, 335.61000000000001, 335.60000000000002, 331.61000000000001, 331.60000000000002, 325.90999999999997, 325.89999999999998, 320.40999999999997, 320.39999999999998, 310.81, 310.80000000000001, 294.11000000000001, 294.10000000000002]
# list index out of range
# invalid literal for float(): 30000 PRIZES
# list index out of range
# 2016-01-24
# P =  [2500.0, 1250.0, 1125.0, 1000.0, 1125.0, 750.0, 500.0, 400.0, 300.0, 200.0, 150.0, 100.0, 96.0, 90.0, 85.0, 75.0, 60.0, 45.0, 30.0, 21.43, 15.0, 12.949999999999999, 12.0, 11.0, 9.0, 8.0, 6.0, 5.25, 3.0, 2.5299999999999998, 2.5, 1.4299999999999999]
# L =  [359.80000000000001, 355.81, 355.80000000000001, 355.81, 355.80000000000001, 355.10000000000002, 354.80000000000001, 354.60000000000002, 353.0, 351.19999999999999, 349.69999999999999, 349.50999999999999, 349.5, 349.00999999999999, 349.0, 348.10000000000002, 347.10000000000002, 346.10000000000002, 343.31, 343.30000000000001, 343.11000000000001, 343.10000000000002, 338.50999999999999, 338.5, 330.31, 330.30000000000001, 322.40999999999997, 322.39999999999998, 307.81, 307.80000000000001, 295.50999999999999, 295.5]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-02-02
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 250.0, 200.0, 175.0, 150.0, 250.0, 100.0, 150.0, 75.0, 50.0, 43.329999999999998, 40.0, 35.859999999999999, 30.0, 26.670000000000002, 25.0, 20.0, 16.670000000000002, 15.0, 11.67, 10.0, 9.0, 7.0, 5.4000000000000004, 5.0, 4.2300000000000004, 4.0, 3.3199999999999998, 3.0, 2.8100000000000001, 2.0, 1.3400000000000001]
# L =  [362.0, 360.69999999999999, 359.80000000000001, 353.39999999999998, 352.39999999999998, 352.30000000000001, 351.5, 349.69999999999999, 348.90999999999997, 348.89999999999998, 347.81, 347.80000000000001, 346.81, 346.80000000000001, 345.90999999999997, 345.89999999999998, 345.10000000000002, 342.20999999999998, 342.19999999999999, 339.20999999999998, 339.19999999999999, 335.81, 335.80000000000001, 332.69999999999999, 330.20999999999998, 330.19999999999999, 327.81, 327.80000000000001, 324.40999999999997, 324.39999999999998, 318.90999999999997, 318.89999999999998, 312.61000000000001, 312.60000000000002, 306.90999999999997, 306.89999999999998, 296.90999999999997, 296.89999999999998, 281.31, 281.30000000000001]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-01-25
# P =  [10000.0, 5000.0, 2500.0, 1500.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 200.0, 175.0, 150.0, 125.0, 100.0, 87.5, 75.0, 50.0, 40.0, 30.0, 25.0, 21.25, 20.0, 15.83, 15.0, 12.5, 10.0, 7.6900000000000004, 7.0, 6.5999999999999996, 5.0, 4.4699999999999998, 4.0, 3.71, 3.0, 2.8399999999999999, 2.0, 1.8899999999999999]
# L =  [405.0, 400.80000000000001, 392.10000000000002, 391.69999999999999, 390.10000000000002, 386.89999999999998, 384.89999999999998, 382.80000000000001, 381.19999999999999, 379.31, 379.30000000000001, 377.20999999999998, 377.19999999999999, 373.70999999999998, 373.69999999999999, 371.89999999999998, 366.5, 361.10000000000002, 356.69999999999999, 352.40999999999997, 352.39999999999998, 349.20999999999998, 349.19999999999999, 345.90999999999997, 345.89999999999998, 341.81, 341.80000000000001, 335.50999999999999, 335.5, 327.90999999999997, 327.89999999999998, 321.61000000000001, 321.60000000000002, 308.50999999999999, 308.5, 287.31, 287.30000000000001]
# list index out of range
# invalid literal for float(): 100000 PRIZES
# list index out of range
# 2016-02-01
# P =  [10000.0, 5000.0, 2500.0, 2000.0, 1500.0, 2000.0, 1000.0, 750.0, 500.0, 400.0, 300.0, 200.0, 158.33000000000001, 150.0, 100.0, 75.0, 50.0, 40.0, 35.0, 30.0, 25.0, 23.57, 20.0, 17.5, 15.0, 11.289999999999999, 10.0, 7.2699999999999996, 7.0, 6.5599999999999996, 5.0, 4.7199999999999998, 4.0, 3.4100000000000001, 3.0, 2.1600000000000001, 2.0, 1.0]
# L =  [374.5, 364.60000000000002, 364.31, 364.30000000000001, 364.31, 364.30000000000001, 361.30000000000001, 360.0, 359.89999999999998, 358.10000000000002, 357.5, 355.20999999999998, 355.19999999999999, 354.60000000000002, 353.69999999999999, 350.69999999999999, 347.0, 342.70999999999998, 342.69999999999999, 339.5, 336.20999999999998, 336.19999999999999, 333.61000000000001, 333.60000000000002, 332.11000000000001, 332.10000000000002, 331.00999999999999, 331.0, 324.61000000000001, 324.60000000000002, 318.20999999999998, 318.19999999999999, 313.50999999999999, 313.5, 302.70999999999998, 302.69999999999999, 286.00999999999999, 286.0]
# /Users/andingo/Library/Python/2.7/lib/python/site-packages/ipykernel/__main__.py:26: DeprecationWarning: BaseException.message has been deprecated as of Python 2.6
