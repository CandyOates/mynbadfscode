# %%
# %matplotlib inline
import pandas as pd
import urllib2
import bs4
import re
import datetime
import unidecode
import numpy as np
import time
import itertools
import matplotlib.pyplot as plt
from scipy import stats
plt.rcParams['figure.figsize'] = (12, 16)

# %% [markdown]
# ### TODO:
# - url to player's page is 'http://www.hockey-reference.com/players/%s/%s.html' % (pid[0], pid)
# - url to player's gamelogs is 'http://www.hockey-reference.com/players/%s/%s/gamelog/%d/' % (pid[0], pid, year) where year is the 2nd year of the season (2015-2016 => year=2016)

# %%
def get_player_list():
    BASEURL = 'http://www.hockey-reference.com'
    URL = '%s/players' % BASEURL
    dic = dict(LEAGUE=[], NAME=[], PID=[], START_YEAR=[], END_YEAR=[], POS=[], HEIGHT=[], WEIGHT=[], BIRTHDAY=[])
    for i in range(97, 97+26):
        letter = chr(i)
        url = '%s/%s/' % (URL, letter)
        try:
            page = urllib2.urlopen(url)
        except:
            print letter, 'page not found'
            continue
        html = page.read()
        soup = bs4.BeautifulSoup(html, "lxml")
        
        rows = soup.findAll('tr')[1:]
        for row in rows:
            lg = row['class'][0]
            items = row.findAll('td')
            a = items[0].find('a')
            name = unidecode.unidecode(a.text)
            href = a['href']
            try:
                pid = re.search('/players/%s/(.+)\.html' % letter, href).group(1)
            except:
                continue
            
            try:
                yr0 = int(items[1].text)
            except ValueError:
                yr0 = None
            
            try:
                yr1 = int(items[2].text)
            except ValueError:
                yr1 = None
            
            pos = items[3].text
            hgt = items[4].text
            
            try:
                wgt = int(items[5].text)
            except ValueError:
                wgt = None
            
            try:
                bd = datetime.datetime.strptime(items[6].text, '%B %d, %Y').date()
            except:
                bd = None
            
            dic['LEAGUE'].append(lg)
            dic['NAME'].append(name)
            dic['PID'].append(pid)
            dic['START_YEAR'].append(yr0)
            dic['END_YEAR'].append(yr1)
            dic['POS'].append(pos)
            dic['HEIGHT'].append(hgt)
            dic['WEIGHT'].append(wgt)
            dic['BIRTHDAY'].append(bd)
    return pd.DataFrame(dic)

# pl = get_player_list()

# %%
pl.to_csv('/Users/andingo/Desktop/NHL/data/playerlist.csv')

# %%
pl = pd.read_csv('/Users/andingo/Desktop/NHL/data/playerlist.csv', index_col=0)

# %%
def get_gamelog_url(pid, season):
    return 'http://www.hockey-reference.com/players/%s/%s/gamelog/%d/' % (pid[0], pid, season)

def get_player_gamelogs(pid, season):
    url = get_gamelog_url(pid, season)
    page = urllib2.urlopen(url)
    html = page.read()
    soup = bs4.BeautifulSoup(html, 'lxml')
    
    cols = [x.text for x in soup.findAll('thead')[0].findAll('tr')[1].findAll('th')]
    cols[1] = 'GM_NUM'
    if cols[5] == '':
        cols[5] = 'H/A'
    if cols[7] == '':
        cols[7] = 'W/L'
    FLAG = True
    FLAG2 = True
    for k, col in enumerate(cols):
        if FLAG2:
            if col == 'G':
                cols[k] = 'GM_NUM'
                FLAG2 = False
        if FLAG:
            cols[k] = 'GOAL_%s' % col if col in ('EV','PP','SH','GW') else col
        else:
            cols[k] = 'AST_%s' % col if col in ('EV','PP','SH','GW') else col
        if col == 'GW':
            FLAG = False
    
    output = []
    for row in soup.findAll('tbody')[0].findAll('tr'):
        if row['class'] != ['']:
            continue
        
        items = [x.text for x in row.findAll('td')]
        items = map(lambda x: 0 if x == '' else x, items)
        for i in range(len(items)):
            try:
                if '.' in items[i]:
                    items[i] = float(items[i])
                else:
                    items[i] = int(items[i])
            except:
                try:
                    items[i] = datetime.datetime.strptime(items[i], '%Y-%m-%d').date()
                except:
                    try:
                        m, s = items[i].split(':')
                        items[i] = int(m) + int(s)/60.
                    except:
                        pass
            
        output.append(items)
    
    output = pd.DataFrame(output, columns=cols)
    output['H/A'][output['H/A']==0] = 'v'
    output['PID'] = pid
    output['GID'] = ['%s@%s%s' % (t,o,d) if ha=='@' else '%s@%s%s' % (o,t,d) for i,d,t,ha,o in output[['Date','Tm','H/A','Opp']].itertuples()]
    output['SEASON'] = season
    return output

# gl = get_player_gamelogs(pl.PID.iloc[0], 1999)

# %%
global_stats = pd.read_csv('/Users/andingo/Desktop/NHL/data/global_stats.csv')
goalie_stats = pd.read_csv('/Users/andingo/Desktop/NHL/data/goalie_stats.csv')
try:
    del global_stats['Unnamed: 0']
    del goalie_stats['Unnamed: 0']
except:
    pass
global_stats.Date = [datetime.datetime.strptime(x, '%Y-%m-%d').date() for x in global_stats.Date]
goalie_stats.Date = [datetime.datetime.strptime(x, '%Y-%m-%d').date() for x in goalie_stats.Date]

# %%
start_time = time.time()
global_stats = pd.DataFrame()
goalie_stats = pd.DataFrame()
pids = pl[(pl.END_YEAR==2016) & (pl.LEAGUE=='nhl')].PID
tmp = pl.set_index('PID')
# last_date = np.max(global_stats.Date)
for k, pid in enumerate(pids):
#     if k < 468:
#         continue
    print pid, '%d / %d' % (k, len(pids))
    try:
        gl = get_player_gamelogs(pid, 2016)
#         gl = gl[gl.Date > last_date].copy()
        if tmp.loc[pid].POS != 'G':
            global_stats = global_stats.append(gl, ignore_index=True)
        else:
            goalie_stats = goalie_stats.append(gl, ignore_index=True)
    except Exception, e:
        print pid, 'error in 2016', get_gamelog_url(pid, 2016), e.message
print 'Time Elapsed:', time.time() - start_time

global_stats = global_stats.drop_duplicates()
goalie_stats = goalie_stats.drop_duplicates()
# Out:
# abdelju01 0 / 887
# agozzan01 1 / 887
# allenja01 2 / 887
# alzneka01 3 / 887
# anderfr01 4 / 887
# andercr01 5 / 887
# anderjo05 6 / 887
# anderjo03 7 / 887
# andrean01 8 / 887
# andrisv01 9 / 887
# angelmi01 10 / 887
# anisiar01 11 / 887
# arcobma01 12 / 887
# armiajo01 13 / 887
# arvidvi01 14 / 887
# athanan01 15 / 887
# atkinca01 16 / 887
# bachmri01 17 / 887
# backeda01 18 / 887
# backlmi01 19 / 887
# backsni02 20 / 887
# baertsv01 21 / 887
# bailejo01 22 / 887
# barbema01 23 / 887
# barkoal01 24 / 887
# barrity01 25 / 887
# bartkma01 26 / 887
# bartlvi01 27 / 887
# bassco01 28 / 887
# baunky01 29 / 887
# cullema01 150 / 887
# cunnicr01 151 / 887
# dahlbkl01 152 / 887
# daleytr01 153 / 887
# danauph01 154 / 887
# danoma01 155 / 887
# darlisc01 156 / 887
# datsypa01 157 / 887
# dauphla01 158 / 887
# davidbr01 159 / 887
# dehaaca01 160 / 887
# delarja01 161 / 887
# dekeyda01 162 / 887
# delzomi01 163 / 887
# demeldy01 164 / 887
# demerja01 165 / 887
# deshada01 166 / 887
# desjaan01 167 / 887
# deslani01 168 / 887
# desprsi01 169 / 887
# digiuph01 170 / 887
# dillobr01

# %%
global_stats.to_csv('/Users/andingo/Desktop/NHL/data/global_stats.csv')
goalie_stats.to_csv('/Users/andingo/Desktop/NHL/data/goalie_stats.csv')

# %%
def fantasy_points(GL):
    gl = GL.copy()
    if 'GA' in gl.keys():
        try:
            gl['DK'] = 3*(gl['W/L']=='W') - gl.GA + .2*gl.SV + gl.SO
        except KeyError:
            gl['DK'] = 3*gl.W - gl.GA + .2*gl.SV + gl.SO
        gl['FD'] = gl.DK
    else:
        gl['DK'] = 3*gl.G + 2*gl.A + .5*gl.S + .5*gl.BLK + gl.GOAL_SH + gl.AST_SH + (1.5*(gl.G>=3) if 'HT' not in gl.keys() else 1.5*gl.HT)
        gl['FD'] = 3*gl.G + 2*gl.A + .5*gl.GOAL_PP + .5*gl.AST_PP + .4*gl.S + gl['+/-'] + .25*gl.PIM
    return gl

# %%
global_stats = fantasy_points(global_stats)
goalie_stats = fantasy_points(goalie_stats)

# %%
global_stats[global_stats.Date == datetime.date(2016, 2, 10)]
# Out:
#        +/-   A  AST_EV  AST_PP  AST_SH     Age  BLK  DEC        Date    FO%  \
# 73112    0   0       0       0       0  28-350    1  NaN  2016-02-10    0.0
# 73113  NaN NaN     NaN     NaN     NaN  34-265  NaN    L  2016-02-10    NaN
# 73114    1   1       1       0       0  21-188    0  NaN  2016-02-10   16.7
# 73115    0   0       0       0       0  23-128    0  NaN  2016-02-10    0.0
# 73116    1   0       0       0       0  27-251    0  NaN  2016-02-10    0.0
# 73117    1   0       0       0       0  27-312    0  NaN  2016-02-10    0.0
# 73118   -1   0       0       0       0  26-056    0  NaN  2016-02-10    0.0
# 73119    0   0       0       0       0  26-213    0  NaN  2016-02-10    0.0
# 73120    0   0       0       0       0  39-213    5  NaN  2016-02-10    0.0
# 73121    1   0       0       0       0  28-141    0  NaN  2016-02-10   68.8
# 73122    0   0       0       0       0  34-305    5  NaN  2016-02-10    0.0
# 73123   -2   0       0       0       0  22-051    0  NaN  2016-02-10    0.0
# 73124    0   0       0       0       0  25-132    0  NaN  2016-02-10    0.0
# 73125    0   0       0       0       0  29-356    0  NaN  2016-02-10    0.0
# 73126    0   0       0       0       0  25-352    1  NaN  2016-02-10    0.0
# 73127    1   0       0       0       0  30-210    1  NaN  2016-02-10   50.0
# 73128   -3   0       0       0       0  28-187    0  NaN  2016-02-10   52.4
# 73129    0   0       0       0       0  39-100    1  NaN  2016-02-10   56.3
# 73199 ...     2016    25 NaN NaN    NaN  22.966667  OTT    L  NaN  NaN
# 73200 ...     2016    24 NaN NaN    NaN  16.633333  VAN    W  NaN  NaN
# 73201 ...     2016    24 NaN NaN    NaN  17.316667  VAN    W  NaN  NaN
# 73202 ...     2016    26 NaN NaN    NaN  18.300000  VAN    W  NaN  NaN
# 73203 ...     2016    21 NaN NaN    NaN  14.266667  DET    W  NaN  NaN
# 73204 ...     2016    16 NaN NaN    NaN  10.400000  PIT    L  NaN  NaN
# 73205 ...     2016    31 NaN NaN    NaN  21.350000  DET    W  NaN  NaN
# 73206 ...     2016    28 NaN NaN    NaN  19.983333  OTT    L  NaN  NaN
# 73207 ...     2016    33 NaN NaN    NaN  21.283333  NYR    W  NaN  NaN
# 73208 ...     2016    18 NaN NaN    NaN  13.100000  NYR    W  NaN  NaN
# 73209 ...     2016    21 NaN NaN    NaN  16.383333  NYR    W  NaN  NaN
# 73210 ...     2016    27 NaN NaN    NaN  24.100000  OTT    L  NaN  NaN
# 73211 ...     2016    30 NaN NaN    NaN  24.300000  ARI    L  NaN  NaN
# 73212 ...     2016    15 NaN NaN    NaN  11.083333  PIT    L  NaN  NaN
# 73213 ...     2016    29 NaN NaN    NaN  22.216667  VAN    W  NaN  NaN
# 73214 ...     2016    15 NaN NaN    NaN  11.033333  DET    W  NaN  NaN
# 73215 ...     2016    24 NaN NaN    NaN  22.916667  OTT    L  NaN  NaN
# 73216 ...     2016    28 NaN NaN    NaN  15.883333  ARI    L  NaN  NaN
# 73217 ...     2016    26 NaN NaN    NaN  18.433333  VAN    W  NaN  NaN
# 73218 ...     2016    15 NaN NaN    NaN   9.133333  VAN    W  NaN  NaN
# 73219 ...     2016    21 NaN NaN    NaN  12.983333  VAN    W  NaN  NaN
# 73220 ...     2016    15 NaN NaN    NaN  12.000000  OTT    L  NaN  NaN
# 73221 ...     2016    17 NaN NaN    NaN  12.550000  PIT    L  NaN  NaN
# 73222 ...     2016    29 NaN NaN    NaN  22.716667  NYR    W  NaN  NaN
# 73223 ...     2016    22 NaN NaN    NaN  19.333333  DET    W  NaN  NaN
# 73224 ...     2016    25 NaN NaN    NaN  17.250000  OTT    L  NaN  NaN
# 73225 ...     2016    22 NaN NaN    NaN  16.466667  NYR    W  NaN  NaN
#
# [114 rows x 40 columns]

# %% [markdown]
# ## Projections

# %%
def get_pid(name, pl, **kwargs):
    I = pl.NAME == name
    if not any(I):
        raise Exception('%s not found' % name)
    for col, st in kwargs.iteritems():
        I = I & (pl[col] == st)
    if not any(I):
        raise Exception('%s not found with specifications %s' % (name, kwargs))
    return pl[I].PID.iloc[0]

# %%
NAME_CORRECTIONS = {
    'Alexander Ovechkin' : 'Alex Ovechkin',
    'Johnny Gaudreau' : 'John Gaudreau',
    'Jon Quick' : 'Jonathan Quick',
    "Matthew O'Connor" : "Matt O'Connor",
    'Cameron Talbot' : 'Cam Talbot',
    'Jacob Muzzin' : 'Jake Muzzin',
    'Samuel Bennett' : 'Sam Bennett',
    'Michael Ferland' : 'Micheal Ferland',
    'Pierre Parenteau' : 'P.A. Parenteau',
    'Viatcheslav Voynov' : 'Slava Voynov',
    'Alex Burmistrov' : 'Alexander Burmistrov',
    'Trevor Van Riemsdyk' : 'Trevor van Riemsdyk',
    'Dylan Demelo' : 'Dylan DeMelo',
    'Tobias Enstrom' : 'Toby Enstrom',
    'Chris Vande Velde' : 'Chris VandeVelde',
    'Joe Morrow' : 'Joseph Morrow',
    'Andew Miller' : 'Andrew Miller',
    'Phil Varone' : 'Philip Varone',
    'Richard Clune' : 'Rich Clune',
    'Max Talbot' : 'Maxime Talbot',
    'Yevgeni Medvedev' : 'Evgeny Medvedev',
}

# %%
TEAM_CORRECTION = dict(itertools.izip(
    ['ANH', 'ARI', 'BOS', 'BUF', 'CAR', 'CLS', 'CGY', 'CHI', 'COL',
   'DAL', 'DET', 'EDM', 'FLA', 'LA', 'MIN', 'MTL', 'NJD', 'NSH',
   'NYI', 'NYR', 'OTT', 'PHI', 'PIT', 'SJ', 'STL', 'TBL', 'TOR',
   'VAN', 'WPG', 'WAS'],
    ['ANA', 'ARI', 'BOS', 'BUF', 'CAR', 'CBJ', 'CGY', 'CHI', 'COL',
   'DAL', 'DET', 'EDM', 'FLA', 'LAK', 'MIN', 'MTL', 'NJD', 'NSH',
   'NYI', 'NYR', 'OTT', 'PHI', 'PIT', 'SJS', 'STL', 'TBL', 'TOR',
   'VAN', 'WPG', 'WSH']
))

# %%
fdpl = pd.read_csv('/Users/andingo/Desktop/NHL/PlayerLists/pl_fd_nhl_2016-02-11.csv')
fdpl['NAME'] = ['%s %s' % (f,l) for f,l in itertools.izip(fdpl['First Name'], fdpl['Last Name'])]
fdpl['PID'] = [get_pid(NAME_CORRECTIONS[x], pl) if x in NAME_CORRECTIONS else get_pid(x, pl) for x in fdpl.NAME]
fdpl.Team = map(lambda x: TEAM_CORRECTION[x], fdpl.Team)
fdpl.Opponent = map(lambda x: TEAM_CORRECTION[x], fdpl.Opponent)
del fdpl['Unnamed: 12']
del fdpl['Unnamed: 13']
fdpl
# for x in fdpl.NAME:
#     try:
#         get_pid(NAME_CORRECTIONS[x], pl) if x in NAME_CORRECTIONS else get_pid(x, pl)
#     except Exception, e:
#         print e.message
# Out:
#               Id Position First Name    Last Name      FPPG  Played  Salary  \
# 0     14675-8273        G      Corey     Crawford  5.834783      46   10200
# 1     14675-9416        G     Braden       Holtby  5.627907      43    9900
# 2     14675-8718       LW  Alexander     Ovechkin  5.158000      50    9500
# 3     14675-8732        G     Semyon     Varlamov  4.583784      37    9300
# 4     14675-8986       LW      Jamie         Benn  4.706481      54    9100
# 5     14675-8494        C       John      Tavares  3.561224      49    8900
# 6     14675-9302        G     Michal     Neuvirth  5.476190      21    8700
# 7     14675-8633        G     Thomas       Greiss  5.554545      22    8600
# 8    14675-54514       LW     Johnny     Gaudreau  3.729412      51    8500
# 9     14675-8262       RW    Patrick         Kane  5.328070      57    8500
# 506  14675-62816       LW      Anton    Slepyshev -0.045455      11    3000
# 507  14675-37880        C      Scott     Laughton  1.102885      52    3000
# 508  14675-62785        D    Yevgeni     Medvedev  1.575676      37    3000
# 509  14675-62789        C     Joonas   Kemppainen  0.257143      35    3000
#
#         Game Team Opponent Injury Indicator Injury Details  \
# 0    DAL@CHI  CHI      DAL              NaN            NaN
# 1    WAS@MIN  WSH      MIN              NaN            NaN
# 2    WAS@MIN  WSH      MIN              NaN            NaN
# 3    COL@OTT  COL      OTT              NaN            NaN
# 4    DAL@CHI  DAL      CHI              NaN            NaN
# 5     LA@NYI  NYI      LAK              NaN            NaN
# 6    BUF@PHI  PHI      BUF              NaN            NaN
# 7     LA@NYI  NYI      LAK              NaN            NaN
# 8     CGY@SJ  CGY      SJS              DTD     Suspension
# 9    DAL@CHI  CHI      DAL              NaN            NaN
# 10   BOS@WPG  BOS      WPG              NaN            NaN
# 11   ANH@CLS  ANA      CBJ              NaN            NaN
# 12   DAL@CHI  CHI      DAL              NaN            NaN
# 13    LA@NYI  LAK      NYI              DTD     Lower body
# 14    CGY@SJ  SJS      CGY              NaN            NaN
# 15   BUF@PHI  BUF      PHI              NaN            NaN
# 16    CGY@SJ  SJS      CGY              NaN            NaN
# 17   ANH@CLS  CBJ      ANA               IR          Groin
# 18   DAL@CHI  CHI      DAL              NaN            NaN
# 19   ANH@CLS  ANA      CBJ              NaN            NaN
# 20    LA@NYI  NYI      LAK              NaN            NaN
# 21   ANH@CLS  CBJ      ANA              NaN            NaN
# 22   DAL@CHI  DAL      CHI              NaN            NaN
# 23   BOS@WPG  BOS      WPG              NaN            NaN
# 24   ANH@CLS  ANA      CBJ              NaN            NaN
# 25   BUF@PHI  PHI      BUF              NaN            NaN
# 26   DAL@CHI  DAL      CHI              NaN            NaN
# 27    LA@NYI  LAK      NYI              NaN            NaN
# 28   COL@OTT  OTT      COL              NaN            NaN
# 29   BUF@PHI  PHI      BUF              NaN            NaN
# ..       ...  ...      ...              ...            ...
# 480  COL@OTT  COL      OTT               IR           Back
# 481  WAS@MIN  WSH      MIN              NaN            NaN
# 482  COL@OTT  COL      OTT              NaN            NaN
# 483  ANH@CLS  CBJ      ANA              NaN            NaN
# 484  TOR@EDM  EDM      TOR              NaN            NaN
# 485   CGY@SJ  CGY      SJS              NaN            NaN
# 486   CGY@SJ  CGY      SJS              NaN            NaN
# 487  DAL@CHI  CHI      DAL              NaN            NaN
# 488   CGY@SJ  SJS      CGY              NaN            NaN
# 489  COL@OTT  OTT      COL              NaN            NaN
# 490  WAS@MIN  WSH      MIN              DTD    Undisclosed
# 491   CGY@SJ  SJS      CGY              NaN            NaN
# 492   CGY@SJ  SJS      CGY              NaN            NaN
# 493  WAS@MIN  MIN      WSH              NaN            NaN
# 494  BUF@PHI  BUF      PHI              NaN            NaN
# 495  DAL@CHI  CHI      DAL              NaN            NaN
# 496   CGY@SJ  CGY      SJS              NaN            NaN
# 497  BUF@PHI  BUF      PHI              NaN            NaN
# 498  DAL@CHI  DAL      CHI              NaN            NaN
# 499  COL@OTT  COL      OTT              NaN            NaN
# 500  TOR@EDM  TOR      EDM              NaN            NaN
# 501  BOS@WPG  BOS      WPG              NaN            NaN
# 502   CGY@SJ  CGY      SJS              NaN            NaN
# 503  WAS@MIN  MIN      WSH              NaN            NaN
# 504  BOS@WPG  BOS      WPG              NaN            NaN
# 505  WAS@MIN  WSH      MIN               IR     Lower body
# 506  TOR@EDM  EDM      TOR              NaN            NaN
# 507  BUF@PHI  PHI      BUF              NaN            NaN
# 508  BUF@PHI  PHI      BUF              NaN            NaN
# 509  BOS@WPG  BOS      WPG              NaN            NaN
#
#                       NAME        PID
# 0           Corey Crawford  crawfco01
# 1            Braden Holtby  holtbbr01
# 2       Alexander Ovechkin  ovechal01
# 3          Semyon Varlamov  varlasi01
# 4               Jamie Benn   bennja01
# 5             John Tavares  tavarjo01
# 6          Michal Neuvirth  neuvimi01
# 7            Thomas Greiss  greisth01
# 8          Johnny Gaudreau  gaudrjo01
# 9             Patrick Kane   kanepa01
# 10             Tuukka Rask   rasktu01
# 11       Frederik Andersen  anderfr01
# 12          Jonathan Toews  toewsjo01
# 13               Jon Quick  quickjo01
# 14            Joe Pavelski  paveljo01
# 15            Chad Johnson  johnsch02
# 16            Martin Jones  jonesma02
# 17        Sergei Bobrovsky  bobrose01
# 18           Scott Darling  darlisc01
# 19            Ryan Getzlaf  getzlry01
# 20          Jaroslav Halak  halakja01
# 21        Joonas Korpisalo  korpijo01
# 22           Kari Lehtonen  lehtoka01
# 23           Brad Marchand  marchbr03
# 24             John Gibson  gibsojo01
# 25           Claude Giroux  giroucl01
# 26            Tyler Seguin  seguity01
# 27           Jhonas Enroth  enrotjh01
# 28          Craig Anderson  andercr01
# 29           Jakub Voracek  voracja01
# ..                     ...        ...
# 480            Brad Stuart  stuarbr02
# 481       Stanislav Galiev  galiest01
# 482         Mikko Rantanen  rantami01
# 483       Gregory Campbell  campbgr01
# 484             Mark Fayne  faynema01
# 485          Ladislav Smid   smidla01
# 486         Brandon Bollig  bollibr01
# 487        Michal Rozsival  rozsimi01
# 488         Ryan Carpenter  carpery01
# 489             Chris Neil   neilch01
# 490          Mike Richards  richami02
# 491          Mirco Mueller  muellmi01
# 492        Barclay Goodrow  goodrba01
# 493         Kurtis Gabriel  gabriku01
# 494    Nicolas Deslauriers  deslani01
# 495           Ryan Hartman  hartmry01
# 496         Jakub Nakladal  naklaja01
# 497       Carlo Colaiacovo  colaica01
# 498            Jordie Benn   bennjo01
# 499      Andreas Martinsen  martian01
# 500       Scott Harrington  harrisc01
# 501  Alexander Khokhlachev  khokhal01
# 502            Matt Stajan  stajama01
# 503        Gustav Olofsson  olofsgu01
# 504             Max Talbot  talboma01
# 505           Brooks Orpik  orpikbr01
# 506        Anton Slepyshev  slepyan01
# 507         Scott Laughton  laughsc01
# 508       Yevgeni Medvedev  medveev01
# 509      Joonas Kemppainen  kemppjo01
#
# [510 rows x 14 columns]

# %%
FIELD_PROJS = pd.DataFrame()
GOALIE_PROJS = pd.DataFrame()
for pid in fdpl.PID:
    I = global_stats.PID == pid
    if any(I):
        sub = global_stats[I]
        mins = sub.TOI.sum()
        if sub.S.sum() > 0:
            sperc = float(sub.G.sum()) / sub.S.sum()
        else:
            sperc = 0.01
        proj = sub.copy()[['A','+/-','PIM','GOAL_PP','AST_PP','GOAL_SH','AST_SH','S','BLK']].sum() / mins
        proj['G'] = proj.S * sperc
        proj['PID'] = pid
        FIELD_PROJS = FIELD_PROJS.append(proj, ignore_index=True)
    else:
        sub = goalie_stats[goalie_stats.PID==pid]
        mins = sub.TOI.sum()
        proj = pd.Series()
        if (sub.GA + sub.SV).sum() > 0:
            proj['SV%'] = float(sub.SV.sum()) / (sub.GA + sub.SV).sum()
        else:
            proj['SV%'] = .85
        proj['PID'] = pid
        GOALIE_PROJS = GOALIE_PROJS.append(proj, ignore_index=True)
GOALIE_PROJS = GOALIE_PROJS.set_index('PID')
FIELD_PROJS = FIELD_PROJS.set_index('PID')

# %% [markdown]
# ## Idiosyncratic Adjustment

# %%
adj = {}
for team in np.unique(fdpl.Team):
    sub = global_stats[global_stats.Opp==team].copy()
    adj[team] = {}
    for st in ('G','A','+/-','PIM','GOAL_PP','GOAL_SH','AST_PP','AST_SH','BLK','S'):
        act = sub[st]
        prj = np.array(sub.TOI) * FIELD_PROJS[st].loc[sub.PID.tolist()]
        I = (~np.isnan(act.tolist())) & (~np.isnan(prj.tolist()))
        b = np.array(act[I]).dot(prj[I].tolist()) / np.array(prj[I].tolist()).dot(prj[I].tolist())
        adj[team][st] = b

# %% [markdown]
# ## Make Adjustments

# %%
FIELD_PROJS
# Out:
#                 +/-         A    AST_PP    AST_SH       BLK         G  \
# PID
# ovechal01  0.014291  0.014100  0.003287  0.000000  0.016996  0.028808
# bennja01   0.006667  0.026553  0.005263  0.001789  0.031691  0.018354
# tavarjo01  0.001023  0.023887  0.009001  0.000215  0.021431  0.020105
# gaudrjo01  0.006149  0.029617  0.009671  0.000000  0.014196  0.019291
# kanepa01   0.012598  0.039270  0.011872  0.000000  0.013699  0.026172
# toewsjo01  0.016139  0.023762  0.004702  0.002033  0.015825  0.019370
# paveljo01  0.014432  0.021519  0.007533  0.000000  0.049966  0.022772
# getzlry01  0.011901  0.037404  0.008664  0.000000  0.041207  0.014808
# marchbr03  0.007121  0.013461  0.001143  0.000484  0.026425  0.022001
# giroucl01 -0.002519  0.030072  0.013583  0.000356  0.014502  0.016645
# seguity01  0.004380  0.024421  0.008817  0.000000  0.019663  0.021149
# voracja01 -0.000500  0.039683  0.015643  0.000000  0.015198  0.013307
# kopitan01  0.007589  0.029740  0.008286  0.000552  0.034474  0.010749
# monahse01  0.002143  0.020603  0.006100  0.000544  0.025281  0.019061
# parisza01  0.004072  0.017388  0.005419  0.000000  0.034603  0.017072
# perryco01  0.005725  0.021593  0.005557  0.000000  0.019427  0.030774
# monahse01  0.005834  0.000267  0.011011  0.110685
# parisza01  0.008128  0.000000  0.028141  0.172142
# perryco01  0.006096  0.000000  0.065101  0.192080
# byfugdu01  0.003078  0.000265  0.049800  0.140290
# simmowa01  0.010456  0.000000  0.062230  0.196689
# duchema01  0.003142  0.000000  0.011490  0.161161
# vanrija01  0.005756  0.000194  0.014252  0.179375
# kaneev01   0.005381  0.000580  0.061478  0.206766
# kuzneev01  0.001653  0.000000  0.019094  0.113783
# mcdavco01  0.006261  0.000000  0.019032  0.131249
# backsni02  0.001067  0.000000  0.018574  0.084981
# coutulo01  0.001533  0.000770  0.004659  0.163578
# carteje01  0.003517  0.000942  0.013722  0.150048
# bergepa01  0.007777  0.000420  0.036554  0.156263
# wheelbl01  0.001696  0.001752  0.026359  0.163730
# burnsbr01  0.001649  0.000223  0.013634  0.137251
# mackina01  0.004215  0.000000  0.026423  0.197953
# ...             ...       ...       ...       ...
# wiercpa01  0.000715  0.000000  0.029441  0.083681
# stuarbr02  0.000000  0.000000  0.012062  0.051774
# galiest01  0.000000  0.000000  0.021331  0.107153
# rantami01  0.000000  0.000000  0.000000  0.144199
# campbgr01  0.000000  0.001102  0.088775  0.065225
# faynema01  0.000000  0.000000  0.008195  0.071930
# smidla01   0.000000  0.000000  0.038189  0.042739
# bollibr01  0.000000  0.000000  0.244305  0.113859
# rozsimi01  0.000000  0.000000  0.020494  0.052795
# carpery01  0.000000  0.000000  0.000000  0.000000
# neilch01   0.001527  0.000000  0.245218  0.101730
# richami02  0.000571  0.000000  0.041387  0.078497
# muellmi01  0.000000  0.000000  0.009966  0.050643
# goodrba01  0.000000  0.000000  0.028384  0.092462
# gabriku01  0.000000  0.000000  0.801429  0.069032
# deslani01  0.000000  0.000000  0.056656  0.088685
# hartmry01  0.000000  0.000000  0.029145  0.161150
# colaica01  0.000000  0.000000  0.013602  0.077272
# bennjo01   0.000000  0.000000  0.009562  0.050788
# martian01  0.000000  0.000000  0.057644  0.103093
# harrisc01  0.000000  0.000000  0.014939  0.054984
# khokhal01  0.000000  0.000000  0.000000  0.062105
# stajama01  0.000000  0.000495  0.053738  0.055163
# olofsgu01  0.000000  0.000000  0.000000  0.050632
# talboma01  0.000000  0.000000  0.034900  0.077775
# orpikbr01  0.000000  0.000000  0.033692  0.036978
# slepyan01  0.000000  0.000000  0.015796  0.064079
# laughsc01  0.000000  0.000000  0.035815  0.162220
# medveev01  0.000000  0.000000  0.032316  0.115739
# kemppjo01  0.000000  0.000000  0.011055  0.064137
#
# [447 rows x 10 columns]

# %% [markdown]
# ## Project TOI and Finalize Projections

# %%
TOI_OVERRIDES = {
    
}

for pid in ADJ_PROJS.index:
    try:
        toi = TOI_OVERRIDES[pid]
    except KeyError:
        toi = global_stats[(global_stats.PID==pid) & (global_stats.SEASON==2016)].TOI
    ADJ_PROJS.set_value(pid, 'TOI', 1)
    ADJ_PROJS.loc[pid] *= .5*toi.mean() + .5*toi.median()
# jonesma02  4.816892
# bobrose01  5.268608
# darlisc01  4.340469
# halakja01  4.220045
# korpijo01  5.268608
# lehtoka01  7.297033
# gibsojo01  4.713788
# enrotjh01  5.403180
# andercr01  5.289028
# masonst01  6.625112
# karlser02  5.289028
# berrare01  6.572797
# kuempda01  7.728169
# pickaca01  6.572797
# backsni01  7.728169
# dubnyde01  7.728169
# niemian02  7.297033
# tokardu01  4.713788
# ramoka01   3.427524
# ullmali01  6.679831
# pavelon01  3.123584
# ...             ...
# oconnma01  5.289028
# talboca01  5.867216
# grubaph01  3.768976
# hammoan01  5.289028
# hallta01   5.867216
# bernijo01  5.186766
# lehnero01  6.679831
# gustajo01  5.777746
# helleco01  3.123584
# ortiojo01  3.427524
# staloal01  4.816892
# forsban01  5.268608
# hutchmi01  3.123584
# mcelhcu01  5.268608
# nilssan01  5.867216
# irvinle01  7.728169
# hoffmmi01  5.289028
# sparkga01  5.186766
# stolaan01  6.625112
# berubje02  4.220045
# gustaer01  4.340469
# larssjo01  6.679831
# martima01  4.220045
# kuldaar01  3.123584
# catenda01  6.679831
# bertsch01  7.728169
# bissopa01  5.403180
# brownmi03  4.816892
# perrofr01  5.289028
# naklaja01  3.427524
#
# [63 rows x 8 columns]

# %%
for game in np.unique(fdpl.Game):
    a, h = game.split('@')
    print '"%s"'%TEAM_CORRECTION[a],':,'
    print '"%s"'%TEAM_CORRECTION[h],':,'
# Out:
# "ANA" :,
# "CBJ" :,
# "BOS" :,
# "WPG" :,
# "BUF" :,
# "PHI" :,
# "CGY" :,
# "SJS" :,
# "COL" :,
# "OTT" :,
# "DAL" :,
# "CHI" :,
# "LAK" :,
# "NYI" :,
# "TOR" :,
# "EDM" :,
# "WSH" :,
# "MIN" :,

# %%
WIN_ODDS = {
"ANA" : .19,
"CBJ" : .81,
"BOS" : .82,
"WPG" : .18,
"BUF" : .645,
"PHI" : .355,
"CGY" : .5,
"SJS" : .5,
"COL" : .5,
"OTT" : .5,
"DAL" : .78,
"CHI" : .22,
"LAK" : .5,
"NYI" : .5,
"TOR" : .625,
"EDM" : .375,
"WSH" : .13,
"MIN" : .87,
}

# %%
for pid in GOALIE_PROJS.index:
    opp = fdpl.set_index('PID').loc[pid].Opponent
    tm = fdpl.set_index('PID').loc[pid].Team
    sub = fdpl[fdpl.Opponent==opp]
    tmp = ADJ_PROJS.loc[sub.PID.tolist()]
    GOALIE_PROJS.set_value(pid, 'GA', tmp.G.sum())
    GOALIE_PROJS.set_value(pid, 'SV', tmp.S.sum()-tmp.G.sum())
    GOALIE_PROJS.set_value(pid, 'SO', stats.poisson.pmf(0, GOALIE_PROJS.loc[pid].GA))
    GOALIE_PROJS.set_value(pid, 'W', WIN_ODDS[tm])
    GOALIE_PROJS.set_value(pid, 'SV%', GOALIE_PROJS.loc[pid].SV / (GOALIE_PROJS.loc[pid].GA + GOALIE_PROJS.loc[pid].SV))
    GOALIE_PROJS.loc[pid] *= GOALIE_PROJS.loc[pid].TOI / 60.
GOALIE_PROJS
# Out:
#                 SV%  TOI        GA         SV        SO      W        DK  \
# PID
# crawfco01  0.907902   60  3.764162  37.107222  0.023187  0.220  4.340469
# holtbbr01  0.913943   60  2.959972  31.435638  0.051820  0.130  3.768976
# varlasi01  0.931225   60  2.939006  39.794424  0.052918  0.500  6.572797
# neuvimi01  0.000000    0  0.000000   0.000000  0.000000  0.000  0.000000
# harrisc01       NaN  0.011210
# khokhal01       NaN -0.232332
# stajama01  1.307714  1.154265
# olofsgu01       NaN  0.186157
# talboma01  1.231970  0.812532
# orpikbr01  1.685066  0.866466
# slepyan01       NaN  0.208193
# laughsc01  1.514028  1.301724
# medveev01  1.968309  1.759832
# kemppjo01  0.901476  0.257733
#
# [447 rows x 14 columns]

# %%
PROJS = FIELDER_PROJS.copy()[['FD','DK']]
PROJS = PROJS.append(GOALIE_PROJS.copy()[['FD','DK']])
PROJS['Pos'] = map(lambda x: fdpl.set_index('PID').loc[x].Position, PROJS.index)
PROJS['Salary'] = map(lambda x: fdpl.set_index('PID').loc[x].Salary, PROJS.index)
PROJS['Team'] = map(lambda x: fdpl.set_index('PID').loc[x].Team, PROJS.index)
PROJS['Game'] = map(lambda x: fdpl.set_index('PID').loc[x].Game, PROJS.index)
PROJS['Name'] = map(lambda x: fdpl.set_index('PID').loc[x].NAME, PROJS.index)
PROJS['Status'] = map(lambda x: fdpl.set_index('PID').loc[x]['Injury Indicator'], PROJS.index)
PROJS
# Out:
#                  FD        DK Pos  Salary Team     Game                  Name  \
# PID
# ovechal01  4.535993  4.618743  LW    9500  WSH  WAS@MIN    Alexander Ovechkin
# bennja01   3.315470  3.734668  LW    9100  DAL  DAL@CHI            Jamie Benn
# tavarjo01  3.389709  3.645789   C    8900  NYI   LA@NYI          John Tavares
# gaudrjo01  3.743237  3.807904  LW    8500  CGY   CGY@SJ       Johnny Gaudreau
# kanepa01   5.455621  5.476420  RW    8500  CHI  DAL@CHI          Patrick Kane
# toewsjo01  3.777828  3.953430   C    8200  CHI  DAL@CHI        Jonathan Toews
# paveljo01  3.948791  4.287491  RW    8200  SJS   CGY@SJ          Joe Pavelski
# getzlry01  4.452728  4.397946   C    8000  ANA  ANH@CLS          Ryan Getzlaf
# marchbr03  3.414981  3.392433  LW    7800  BOS  BOS@WPG         Brad Marchand
# giroucl01  4.496470  4.775944   C    7800  PHI  BUF@PHI         Claude Giroux
# seguity01  3.539066  3.909667   C    7800  DAL  DAL@CHI          Tyler Seguin
# voracja01  4.281341  4.441357  LW    7700  PHI  BUF@PHI         Jakub Voracek
# kopitan01  2.924413  3.219385   C    7600  LAK   LA@NYI          Anze Kopitar
# monahse01  3.114492  3.404166   C    7500  CGY   CGY@SJ          Sean Monahan
# parisza01  3.070116  3.428171  LW    7400  MIN  WAS@MIN           Zach Parise
# perryco01  4.759579  4.765221  RW    7300  ANA  ANH@CLS           Corey Perry
# byfugdu01  4.074427  4.391708   D    7300  WPG  BOS@WPG      Dustin Byfuglien
# simmowa01  3.840252  3.975303  RW    7300  PHI  BUF@PHI        Wayne Simmonds
# duchema01  2.949398  3.520191  RW    7200  COL  COL@OTT          Matt Duchene
# vanrija01  3.334077  3.919280  LW    7100  TOR  TOR@EDM    James van Riemsdyk
# kaneev01   3.392186  3.713792  LW    7100  BUF  BUF@PHI          Evander Kane
# kuzneev01  2.894747  2.655839   C    7000  WSH  WAS@MIN      Evgeny Kuznetsov
# mcdavco01  4.340869  4.585517   C    6900  EDM  TOR@EDM        Connor McDavid
# backsni02  2.834647  2.837180   C    6900  WSH  WAS@MIN     Nicklas Backstrom
# coutulo01  2.783374  3.406080   C    6800  SJS   CGY@SJ         Logan Couture
# carteje01  3.103592  3.375559   C    6800  LAK   LA@NYI           Jeff Carter
# bergepa01  3.584191  3.903405   C    6700  BOS  BOS@WPG      Patrice Bergeron
# wheelbl01  4.356048  4.605768  RW    6700  WPG  BOS@WPG         Blake Wheeler
# burnsbr01  3.172822  4.670977   D    6700  SJS   CGY@SJ           Brent Burns
# mackina01  3.249460  3.946868   C    6600  COL  COL@OTT      Nathan MacKinnon
# ...             ...       ...  ..     ...  ...      ...                   ...
# oconnma01  0.000000  0.000000   G    7200  OTT  COL@OTT      Matthew O'Connor
# talboca01  0.000000  0.000000   G    7200  EDM  TOR@EDM        Cameron Talbot
# grubaph01  0.000000  0.000000   G    7200  WSH  WAS@MIN      Philipp Grubauer
# hammoan01  5.289028  5.289028   G    7100  OTT  COL@OTT        Andrew Hammond
# hallta01   0.000000  0.000000  LW    7100  EDM  TOR@EDM           Taylor Hall
# bernijo01  5.186766  5.186766   G    7000  TOR  TOR@EDM      Jonathan Bernier
# lehnero01  6.679831  6.679831   G    6900  BUF  BUF@PHI          Robin Lehner
# gustajo01  0.000000  0.000000   G    6900  BOS  BOS@WPG      Jonas Gustavsson
# helleco01  0.000000  0.000000   G    6600  WPG  BOS@WPG     Connor Hellebuyck
# ortiojo01  0.000000  0.000000   G    6500  CGY   CGY@SJ            Joni Ortio
# staloal01  4.816892  4.816892   G    6500  SJS   CGY@SJ          Alex Stalock
# forsban01  0.000000  0.000000   G    6400  CBJ  ANH@CLS        Anton Forsberg
# hutchmi01  0.000000  0.000000   G    6400  WPG  BOS@WPG    Michael Hutchinson
# mcelhcu01  0.000000  0.000000   G    6300  CBJ  ANH@CLS     Curtis McElhinney
# nilssan01  0.000000  0.000000   G    6300  EDM  TOR@EDM        Anders Nilsson
# irvinle01  0.000000  0.000000   G    6200  MIN  WAS@MIN         Leland Irving
# hoffmmi01  0.000000  0.000000  LW    5800  OTT  COL@OTT          Mike Hoffman
# sparkga01  0.000000  0.000000   G    4900  TOR  TOR@EDM         Garret Sparks
# stolaan01  0.000000  0.000000   G    4900  PHI  BUF@PHI       Anthony Stolarz
# berubje02  0.000000  0.000000   G    4800  NYI   LA@NYI  Jean-Francois Berube
# gustaer01  0.000000  0.000000   D    3300  CHI  DAL@CHI       Erik Gustafsson
# larssjo01  0.000000  0.000000   C    3200  BUF  BUF@PHI         Johan Larsson
# martima01  0.000000  0.000000  LW    3100  NYI   LA@NYI           Matt Martin
# kuldaar01  0.000000  0.000000   D    3100  WPG  BOS@WPG          Arturs Kulda
# catenda01  0.000000  0.000000   C    3000  BUF  BUF@PHI      Daniel Catenacci
# bertsch01  0.000000  0.000000  RW    3000  MIN  WAS@MIN    Christoph Bertschy
# bissopa01  0.000000  0.000000   C    3000  LAK   LA@NYI      Paul Bissonnette
# brownmi03  0.000000  0.000000  RW    3000  SJS   CGY@SJ            Mike Brown
# perrofr01  0.000000  0.000000  LW    3000  OTT  COL@OTT        Francis Perron
# naklaja01  0.000000  0.000000   D    3000  CGY   CGY@SJ        Jakub Nakladal
#
#           Status
# PID
# ovechal01    NaN
# bennja01     NaN
# tavarjo01    NaN
# gaudrjo01    DTD
# kanepa01     NaN
# toewsjo01    NaN
# paveljo01    NaN
# getzlry01    NaN
# marchbr03    NaN
# giroucl01    NaN
# seguity01    NaN
# voracja01    NaN
# kopitan01    NaN
# monahse01    DTD
# parisza01    NaN
# perryco01    NaN
# byfugdu01    NaN
# simmowa01    NaN
# duchema01    NaN
# vanrija01     IR
# kaneev01     NaN
# kuzneev01    NaN
# mcdavco01    NaN
# backsni02    NaN
# coutulo01    NaN
# carteje01    NaN
# bergepa01    NaN
# wheelbl01    NaN
# burnsbr01    NaN
# mackina01    NaN
# ...          ...
# oconnma01    NaN
# talboca01    NaN
# grubaph01    NaN
# hammoan01    NaN
# hallta01     NaN
# bernijo01    NaN
# lehnero01    NaN
# gustajo01    NaN
# helleco01    NaN
# ortiojo01    NaN
# staloal01    NaN
# forsban01    NaN
# hutchmi01    NaN
# mcelhcu01     IR
# nilssan01    NaN
# irvinle01    NaN
# hoffmmi01    NaN
# sparkga01    NaN
# stolaan01    NaN
# berubje02    NaN
# gustaer01    NaN
# larssjo01    DTD
# martima01    NaN
# kuldaar01    NaN
# catenda01    NaN
# bertsch01    NaN
# bissopa01    NaN
# brownmi03    NaN
# perrofr01    NaN
# naklaja01    NaN
#
# [510 rows x 8 columns]

# %% [markdown]
# ## Create Optimizer for Each Site

# %%
import pulp_lineup_optimization as lopt
def get_optimizer(PROJS, site):
    return eval('get_optimizer_%s(PROJS)' % site)

def get_optimizer_FD(PROJS):
    salary = 55000.
    nslots = 9
    
    PROJS['Proj'] = PROJS.FD
    posnums = {'LW': 1, 'RW': 2, 'C': 3, 'D': 4, 'G': 5}
    PROJS['PosNum'] = map(lambda x: posnums[x], PROJS.Pos)
    
    lo = lopt.LineupOptimizer(PROJS, nslots, salary)
    lo.addPositionConstraint('LW', 'eq', 2)
    lo.addPositionConstraint('RW', 'eq', 2)
    lo.addPositionConstraint('C', 'eq', 2)
    lo.addPositionConstraint('D', 'eq', 2)
    lo.addPositionConstraint('G', 'eq', 1)
    
    games = np.unique(PROJS.Game)
    # At least players from 3 teams
    for k, team in enumerate(np.unique(PROJS.Team)):
        for team2 in np.unique(PROJS.Team)[k+1:]:
            lo.addTeamLimitConstraint('%s/%s' % (team,team2), 'le', 8)
        # Max 4 players from a single team
        lo.addTeamLimitConstraint(team, 'le', 4)

    return lo

def get_optimizer_DK(PROJS):
    salary = 50000.
    nslots = 9
    
    PROJS['Proj'] = PROJS.DK
    posnums = {'W': 1, 'C': 2, 'D': 3, 'G': 4}
    PROJS['PosNum'] = map(lambda x: posnums[x], PROJS.Pos)
    
    lo = lopt.LineupOptimizer(PROJS, nslots, salary)
    lo.addPositionConstraint('W/C/D/G', 'eq', nslots)
    lo.addPositionConstraint('W', 'ge', 3)
    lo.addPositionConstraint('C', 'ge', 2)
    lo.addPositionConstraint('D', 'ge', 2)
    lo.addPositionConstraint('G', 'ge', 1)
    
    # At least skates from 3 teams
    for k, team in enumerate(np.unique(PROJS.Team)):
        for team2 in np.unique(PROJS.Team)[k+1:]:
            lo.addCustomConstraint(lambda x: ((x.Team==team) | (x.Team==team2))&(x.Pos!='G'), 'le', 8)
    
    return lo

# %%
I = ~np.isnan(PROJS.FD)
# %time lo = get_optimizer(PROJS[I].copy(), 'FD')

OMITS = [
    'Artemi Panarin',
]

for name in OMITS:
    lo.addPlayerConstraint(get_pid(name, pl), 'eq', 0)

# %time status, lu = lo.solve()
print status
print 'Proj: %.2f' % lu.Proj.sum()
print 'Salary: %.2f' % lu.Salary.sum()
print lu[['Name','Proj','Salary','Pos','Team','Game','Status']]
# Out:
# CPU times: user 372 ms, sys: 83.9 ms, total: 456 ms
# Wall time: 1.56 s
# Optimal
# Proj: 38.97
# Salary: 54700.00
#                           Name      Proj  Salary Pos Team     Game Status
# PID
# laddan01           Andrew Ladd  3.462235    5800  LW  WPG  BOS@WPG    NaN
# perrema01    Mathieu Perreault  3.153158    4600  LW  WPG  BOS@WPG    NaN
# kanepa01          Patrick Kane  5.455621    8500  RW  CHI  DAL@CHI    NaN
# perryco01          Corey Perry  4.759579    7300  RW  ANA  ANH@CLS    NaN
# mcdavco01       Connor McDavid  4.340869    6900   C  EDM  TOR@EDM    NaN
# littlbr01         Bryan Little  3.443816    5400   C  WPG  BOS@WPG    NaN
# gostish01  Shayne Gostisbehere  3.705330    5100   D  PHI  BUF@PHI    NaN
# theodsh01        Shea Theodore  2.924505    3700   D  ANA  ANH@CLS    NaN
# dubnyde01         Devan Dubnyk  7.728169    7400   G  MIN  WAS@MIN    NaN

# %%
print status
print 'Proj: %.2f' % lu.Proj.sum()
print 'Salary: %.2f' % lu.Salary.sum()
print lu[['Name','Proj','Salary','Pos','Team','Game','Status']]
# Out:
# Optimal
# Proj: 38.97
# Salary: 54700.00
#                           Name      Proj  Salary Pos Team     Game Status
# PID
# laddan01           Andrew Ladd  3.462235    5800  LW  WPG  BOS@WPG    NaN
# perrema01    Mathieu Perreault  3.153158    4600  LW  WPG  BOS@WPG    NaN
# kanepa01          Patrick Kane  5.455621    8500  RW  CHI  DAL@CHI    NaN
# perryco01          Corey Perry  4.759579    7300  RW  ANA  ANH@CLS    NaN
# mcdavco01       Connor McDavid  4.340869    6900   C  EDM  TOR@EDM    NaN
# littlbr01         Bryan Little  3.443816    5400   C  WPG  BOS@WPG    NaN
# gostish01  Shayne Gostisbehere  3.705330    5100   D  PHI  BUF@PHI    NaN
# theodsh01        Shea Theodore  2.924505    3700   D  ANA  ANH@CLS    NaN
# dubnyde01         Devan Dubnyk  7.728169    7400   G  MIN  WAS@MIN    NaN
